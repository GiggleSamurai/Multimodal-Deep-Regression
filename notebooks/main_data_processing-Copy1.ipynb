# %%
import torch
import torch.nn as nn

# Inside the /Multimodal-Deep-Regression/notebooks
import sys
sys.path.append("..")

from util.data_utilities import process_data
from util.utilities import get_device

# %%
# This need to same as the main & preprocess
frames_to_skip=200 # how many frame to skip, reduce depth
shrink=8 # shrink H x W, the higher the smaller scale
normalize=False # normalize the pixel to 0 to 1

# %%
process_data(
    input_type='video_pack_1000', 
    addition_parameters={'first_n_videos': 20}, 
    verbose=True,
    device=get_device(),
    skip_frames=True, frames_to_skip=frames_to_skip, shrink=shrink , normalize=normalize
    )
# Out:
# You are using device: cuda
# Currently processing: 7241650246751669546.mp4
# /home/louis/.local/lib/python3.10/site-packages/torchvision/io/video_reader.py:245: UserWarning: Accurate seek is not implemented for pyav backend
#   warnings.warn("Accurate seek is not implemented for pyav backend")
# Downsampling video tensors for every 200 frame
# Original tensor size: (3, 7012, 1024, 576)
# New tensor size: torch.Size([3, 36, 1024, 576])
# Resize to tensor size: torch.Size([3, 36, 128, 72])
# 7241650246751669546
# 63.7
# Done processing: ../data/video_packs/video_pack_1000/7241650246751669546.mp4.
# X Tensor (torch.Size([3, 36, 128, 72])) saved under: ../data/x_tensors/video_pack_1000/7241650246751669546_x_tensor.pt.
# Y Tensor (torch.Size([1, 1])) saved under: ../data/y_tensors/video_pack_1000/7241650246751669546_y_tensor.pt.
# metadata:
# {'video': {'fps': [29.97], 'duration': [233.9673006339673]}, 'audio': {'framerate': [44100.0], 'duration': [233.9619954648526]}}
#
#
# Currently processing: 7218709259020750123.mp4
# Downsampling video tensors for every 200 frame
# Original tensor size: (3, 2358, 1024, 576)
# New tensor size: torch.Size([3, 12, 1024, 576])
# Resize to tensor size: torch.Size([3, 12, 128, 72])
# 7218709259020750123
# 3300.0
# Done processing: ../data/video_packs/video_pack_1000/7218709259020750123.mp4.
# X Tensor (torch.Size([3, 12, 128, 72])) saved under: ../data/x_tensors/video_pack_1000/7218709259020750123_x_tensor.pt.
# Y Tensor (torch.Size([1, 1])) saved under: ../data/y_tensors/video_pack_1000/7218709259020750123_y_tensor.pt.
# metadata:
# {'video': {'fps': [30.0], 'duration': [78.6]}, 'audio': {'framerate': [44100.0], 'duration': [78.64399092970521]}}
#
#
# Currently processing: 7115152040438893870.mp4
# Downsampling video tensors for every 200 frame
# Original tensor size: (3, 632, 1024, 576)
# New tensor size: torch.Size([3, 4, 1024, 576])
# Resize to tensor size: torch.Size([3, 4, 128, 72])
# 7115152040438893870
# 23500.0
# Done processing: ../data/video_packs/video_pack_1000/7115152040438893870.mp4.
# X Tensor (torch.Size([3, 4, 128, 72])) saved under: ../data/x_tensors/video_pack_1000/7115152040438893870_x_tensor.pt.
# Y Tensor (torch.Size([1, 1])) saved under: ../data/y_tensors/video_pack_1000/7115152040438893870_y_tensor.pt.
# metadata:
# {'video': {'fps': [30.0], 'duration': [21.066666666666666]}, 'audio': {'framerate': [44100.0], 'duration': [21.059002267573696]}}
#
#
# Currently processing: 7220126942446636330.mp4
# Downsampling video tensors for every 200 frame
# Original tensor size: (3, 659, 1024, 576)
# New tensor size: torch.Size([3, 4, 1024, 576])
# Resize to tensor size: torch.Size([3, 4, 128, 72])
# 7220126942446636330
# 4000.0
# Done processing: ../data/video_packs/video_pack_1000/7220126942446636330.mp4.
# X Tensor (torch.Size([3, 4, 128, 72])) saved under: ../data/x_tensors/video_pack_1000/7220126942446636330_x_tensor.pt.
# Y Tensor (torch.Size([1, 1])) saved under: ../data/y_tensors/video_pack_1000/7220126942446636330_y_tensor.pt.
# metadata:
# {'video': {'fps': [30.0], 'duration': [21.966666666666665]}, 'audio': {'framerate': [44100.0], 'duration': [21.965011337868482]}}
#
#
# Currently processing: 7164417263250984198.mp4
# Downsampling video tensors for every 200 frame
# Original tensor size: (3, 298, 1024, 576)
# New tensor size: torch.Size([3, 2, 1024, 576])
# Resize to tensor size: torch.Size([3, 2, 128, 72])
# 7164417263250984198
# 53700.0
# Done processing: ../data/video_packs/video_pack_1000/7164417263250984198.mp4.
# X Tensor (torch.Size([3, 2, 128, 72])) saved under: ../data/x_tensors/video_pack_1000/7164417263250984198_x_tensor.pt.
# Y Tensor (torch.Size([1, 1])) saved under: ../data/y_tensors/video_pack_1000/7164417263250984198_y_tensor.pt.
# metadata:
# {'video': {'fps': [30.0], 'duration': [9.933333333333334]}, 'audio': {'framerate': [44100.0], 'duration': [9.959909297052155]}}
#
#
# Currently processing: 7223272643930230021.mp4
# Downsampling video tensors for every 200 frame
# Original tensor size: (3, 649, 1246, 576)
# New tensor size: torch.Size([3, 4, 1246, 576])
# Resize to tensor size: torch.Size([3, 4, 128, 72])
# 7223272643930230021
# 1700.0
# Done processing: ../data/video_packs/video_pack_1000/7223272643930230021.mp4.
# X Tensor (torch.Size([3, 4, 128, 72])) saved under: ../data/x_tensors/video_pack_1000/7223272643930230021_x_tensor.pt.
# Y Tensor (torch.Size([1, 1])) saved under: ../data/y_tensors/video_pack_1000/7223272643930230021_y_tensor.pt.
# metadata:
# {'video': {'fps': [26.652977412731005], 'duration': [24.333333333333332]}, 'audio': {'framerate': [44100.0], 'duration': [24.379002267573696]}}
#
#
# Currently processing: 7208316277855620395.mp4
# Downsampling video tensors for every 200 frame
# Original tensor size: (3, 1474, 1024, 576)
# New tensor size: torch.Size([3, 8, 1024, 576])
# Resize to tensor size: torch.Size([3, 8, 128, 72])
# 7208316277855620395
# 97.0
# Done processing: ../data/video_packs/video_pack_1000/7208316277855620395.mp4.
# X Tensor (torch.Size([3, 8, 128, 72])) saved under: ../data/x_tensors/video_pack_1000/7208316277855620395_x_tensor.pt.
# Y Tensor (torch.Size([1, 1])) saved under: ../data/y_tensors/video_pack_1000/7208316277855620395_y_tensor.pt.
# metadata:
# {'video': {'fps': [55.44827586206897], 'duration': [26.583333333333332]}, 'audio': {'framerate': [44100.0], 'duration': [26.65501133786848]}}
#
#
# Currently processing: 7198252637303688491.mp4
# Downsampling video tensors for every 200 frame
# Original tensor size: (3, 284, 1024, 576)
# New tensor size: torch.Size([3, 2, 1024, 576])
# Resize to tensor size: torch.Size([3, 2, 128, 72])
# 7198252637303688491
# 2800.0
# Done processing: ../data/video_packs/video_pack_1000/7198252637303688491.mp4.
# X Tensor (torch.Size([3, 2, 128, 72])) saved under: ../data/x_tensors/video_pack_1000/7198252637303688491_x_tensor.pt.
# Y Tensor (torch.Size([1, 1])) saved under: ../data/y_tensors/video_pack_1000/7198252637303688491_y_tensor.pt.
# metadata:
# {'video': {'fps': [30.0], 'duration': [9.466666666666667]}, 'audio': {'framerate': [44100.0], 'duration': [9.495011337868482]}}
#
#
# Currently processing: 7214973613269732610.mp4
# Downsampling video tensors for every 200 frame
# Original tensor size: (3, 352, 768, 576)
# New tensor size: torch.Size([3, 2, 768, 576])
# Resize to tensor size: torch.Size([3, 2, 128, 72])
# 7214973613269732610
# 4600.0
# Done processing: ../data/video_packs/video_pack_1000/7214973613269732610.mp4.
# X Tensor (torch.Size([3, 2, 128, 72])) saved under: ../data/x_tensors/video_pack_1000/7214973613269732610_x_tensor.pt.
# Y Tensor (torch.Size([1, 1])) saved under: ../data/y_tensors/video_pack_1000/7214973613269732610_y_tensor.pt.
# metadata:
# {'video': {'fps': [30.0], 'duration': [11.733333333333333]}, 'audio': {'framerate': [44100.0], 'duration': [11.770997732426304]}}
#
#
# Currently processing: 7202785014994570502.mp4
# Downsampling video tensors for every 200 frame
# Original tensor size: (3, 518, 1024, 576)
# New tensor size: torch.Size([3, 3, 1024, 576])
# Resize to tensor size: torch.Size([3, 3, 128, 72])
# 7202785014994570502
# 6000.0
# Done processing: ../data/video_packs/video_pack_1000/7202785014994570502.mp4.
# X Tensor (torch.Size([3, 3, 128, 72])) saved under: ../data/x_tensors/video_pack_1000/7202785014994570502_x_tensor.pt.
# Y Tensor (torch.Size([1, 1])) saved under: ../data/y_tensors/video_pack_1000/7202785014994570502_y_tensor.pt.
# metadata:
# {'video': {'fps': [30.0], 'duration': [17.266666666666666]}, 'audio': {'framerate': [44100.0], 'duration': [17.273990929705214]}}
#
#
# Currently processing: 7146090644782583041.mp4
# Downsampling video tensors for every 200 frame
# Original tensor size: (3, 1028, 1024, 576)
# New tensor size: torch.Size([3, 6, 1024, 576])
# Resize to tensor size: torch.Size([3, 6, 128, 72])
# 7146090644782583041
# 2400.0
# Done processing: ../data/video_packs/video_pack_1000/7146090644782583041.mp4.
# X Tensor (torch.Size([3, 6, 128, 72])) saved under: ../data/x_tensors/video_pack_1000/7146090644782583041_x_tensor.pt.
# Y Tensor (torch.Size([1, 1])) saved under: ../data/y_tensors/video_pack_1000/7146090644782583041_y_tensor.pt.
# metadata:
# {'video': {'fps': [53.541666666666664], 'duration': [19.2]}, 'audio': {'framerate': [44100.0], 'duration': [19.270997732426302]}}
#
#
# Currently processing: 7229798794924248363.mp4
# Downsampling video tensors for every 200 frame
# Original tensor size: (3, 3215, 1024, 576)
# New tensor size: torch.Size([3, 17, 1024, 576])
# Resize to tensor size: torch.Size([3, 17, 128, 72])
# 7229798794924248363
# 45.5
# Done processing: ../data/video_packs/video_pack_1000/7229798794924248363.mp4.
# X Tensor (torch.Size([3, 17, 128, 72])) saved under: ../data/x_tensors/video_pack_1000/7229798794924248363_x_tensor.pt.
# Y Tensor (torch.Size([1, 1])) saved under: ../data/y_tensors/video_pack_1000/7229798794924248363_y_tensor.pt.
# metadata:
# {'video': {'fps': [30.0], 'duration': [107.16666666666667]}, 'audio': {'framerate': [44100.0], 'duration': [107.16]}}
#
#
# Currently processing: 7234000112719105286.mp4
# Downsampling video tensors for every 200 frame
# Original tensor size: (3, 1145, 1024, 576)
# New tensor size: torch.Size([3, 6, 1024, 576])
# Resize to tensor size: torch.Size([3, 6, 128, 72])
# 7234000112719105286
# 4000.0
# Done processing: ../data/video_packs/video_pack_1000/7234000112719105286.mp4.
# X Tensor (torch.Size([3, 6, 128, 72])) saved under: ../data/x_tensors/video_pack_1000/7234000112719105286_x_tensor.pt.
# Y Tensor (torch.Size([1, 1])) saved under: ../data/y_tensors/video_pack_1000/7234000112719105286_y_tensor.pt.
# metadata:
# {'video': {'fps': [30.0], 'duration': [38.166666666666664]}, 'audio': {'framerate': [44100.0], 'duration': [38.14893424036281]}}
#
#
# Currently processing: 7215759966832037166.mp4
# Downsampling video tensors for every 200 frame
# Original tensor size: (3, 964, 1024, 576)
# New tensor size: torch.Size([3, 5, 1024, 576])
# Resize to tensor size: torch.Size([3, 5, 128, 72])
# 7215759966832037166
# 329.5
# Done processing: ../data/video_packs/video_pack_1000/7215759966832037166.mp4.
# X Tensor (torch.Size([3, 5, 128, 72])) saved under: ../data/x_tensors/video_pack_1000/7215759966832037166_x_tensor.pt.
# Y Tensor (torch.Size([1, 1])) saved under: ../data/y_tensors/video_pack_1000/7215759966832037166_y_tensor.pt.
# metadata:
# {'video': {'fps': [30.0], 'duration': [32.13333333333333]}, 'audio': {'framerate': [44100.0], 'duration': [32.15800453514739]}}
#
#
# Currently processing: 7180799213368790277.mp4
# Downsampling video tensors for every 200 frame
# Original tensor size: (3, 899, 1024, 576)
# New tensor size: torch.Size([3, 5, 1024, 576])
# Resize to tensor size: torch.Size([3, 5, 128, 72])
# 7180799213368790277
# 653.3
# Done processing: ../data/video_packs/video_pack_1000/7180799213368790277.mp4.
# X Tensor (torch.Size([3, 5, 128, 72])) saved under: ../data/x_tensors/video_pack_1000/7180799213368790277_x_tensor.pt.
# Y Tensor (torch.Size([1, 1])) saved under: ../data/y_tensors/video_pack_1000/7180799213368790277_y_tensor.pt.
# metadata:
# {'video': {'fps': [42.84352660841938], 'duration': [20.983333333333334]}, 'audio': {'framerate': [44100.0], 'duration': [21.035827664399093]}}
#
#
# Currently processing: 7225482020187589931.mp4
# Downsampling video tensors for every 200 frame
# Original tensor size: (3, 372, 1024, 576)
# New tensor size: torch.Size([3, 2, 1024, 576])
# Resize to tensor size: torch.Size([3, 2, 128, 72])
# 7225482020187589931
# 1800.0
# Done processing: ../data/video_packs/video_pack_1000/7225482020187589931.mp4.
# X Tensor (torch.Size([3, 2, 128, 72])) saved under: ../data/x_tensors/video_pack_1000/7225482020187589931_x_tensor.pt.
# Y Tensor (torch.Size([1, 1])) saved under: ../data/y_tensors/video_pack_1000/7225482020187589931_y_tensor.pt.
# metadata:
# {'video': {'fps': [37.288782816229116], 'duration': [9.976190476190476]}, 'audio': {'framerate': [44100.0], 'duration': [10.03]}}
#
#
# Currently processing: 7214271423676796206.mp4
# Downsampling video tensors for every 200 frame
# Original tensor size: (3, 1301, 1024, 576)
# New tensor size: torch.Size([3, 7, 1024, 576])
# Resize to tensor size: torch.Size([3, 7, 128, 72])
# 7214271423676796206
# 4800.0
# Done processing: ../data/video_packs/video_pack_1000/7214271423676796206.mp4.
# X Tensor (torch.Size([3, 7, 128, 72])) saved under: ../data/x_tensors/video_pack_1000/7214271423676796206_x_tensor.pt.
# Y Tensor (torch.Size([1, 1])) saved under: ../data/y_tensors/video_pack_1000/7214271423676796206_y_tensor.pt.
# metadata:
# {'video': {'fps': [30.0], 'duration': [43.36666666666667]}, 'audio': {'framerate': [44100.0], 'duration': [43.39700680272109]}}
#
#
# Currently processing: 7193999463277432107.mp4
# Downsampling video tensors for every 200 frame
# Original tensor size: (3, 555, 1024, 576)
# New tensor size: torch.Size([3, 3, 1024, 576])
# Resize to tensor size: torch.Size([3, 3, 128, 72])
# 7193999463277432107
# 9600.0
# Done processing: ../data/video_packs/video_pack_1000/7193999463277432107.mp4.
# X Tensor (torch.Size([3, 3, 128, 72])) saved under: ../data/x_tensors/video_pack_1000/7193999463277432107_x_tensor.pt.
# Y Tensor (torch.Size([1, 1])) saved under: ../data/y_tensors/video_pack_1000/7193999463277432107_y_tensor.pt.
# metadata:
# {'video': {'fps': [30.0], 'duration': [18.5]}, 'audio': {'framerate': [44100.0], 'duration': [18.528004535147392]}}
#
#
# Currently processing: 7223104483688025387.mp4
# Downsampling video tensors for every 200 frame
# Original tensor size: (3, 563, 1018, 576)
# New tensor size: torch.Size([3, 3, 1018, 576])
# Resize to tensor size: torch.Size([3, 3, 128, 72])
# 7223104483688025387
# 569.9
# Done processing: ../data/video_packs/video_pack_1000/7223104483688025387.mp4.
# X Tensor (torch.Size([3, 3, 128, 72])) saved under: ../data/x_tensors/video_pack_1000/7223104483688025387_x_tensor.pt.
# Y Tensor (torch.Size([1, 1])) saved under: ../data/y_tensors/video_pack_1000/7223104483688025387_y_tensor.pt.
# metadata:
# {'video': {'fps': [30.0], 'duration': [18.766666666666666]}, 'audio': {'framerate': [44100.0], 'duration': [18.76]}}
#
#
# Currently processing: 7064151368285654278.mp4
# Downsampling video tensors for every 200 frame
# Original tensor size: (3, 570, 1024, 576)
# New tensor size: torch.Size([3, 3, 1024, 576])
# Resize to tensor size: torch.Size([3, 3, 128, 72])
# 7064151368285654278
# 72000.0
# Done processing: ../data/video_packs/video_pack_1000/7064151368285654278.mp4.
# X Tensor (torch.Size([3, 3, 128, 72])) saved under: ../data/x_tensors/video_pack_1000/7064151368285654278_x_tensor.pt.
# Y Tensor (torch.Size([1, 1])) saved under: ../data/y_tensors/video_pack_1000/7064151368285654278_y_tensor.pt.
# metadata:
# {'video': {'fps': [30.0], 'duration': [19.0]}, 'audio': {'framerate': [44100.0], 'duration': [19.03891156462585]}}

# %%
# check on the tensor
import os
import matplotlib.pyplot as plt
from PIL import Image
import numpy as np
from util.data_utilities import get_base_tensor_directories, generate_batch
from util.data_utilities import process_data

device = get_device()
x_dir, y_dir = get_base_tensor_directories(input_type='video_pack_1000')
x_files = sorted([os.path.join(x_dir, f) for f in os.listdir(x_dir)])
x_data = [torch.load(f) for f in x_files]

# select the video & frame
video = 1
frame = 1

# select a frame
image_tensor = x_data[video] [:,frame,:,:]
numpy_image = image_tensor.detach().numpy()

# imshow (Height, Width, Channels)
numpy_image = numpy_image.transpose((1, 2, 0))

# normalize to 0,1
numpy_image = (numpy_image - numpy_image.min()) / (numpy_image.max() - numpy_image.min())

plt.imshow(numpy_image)
plt.show()
# Out:
# You are using device: cuda

# %% [raw]
# process_data(
#     input_type='video_pack_5000',
#     addition_parameters={'first_n_videos': 5},
#     verbose=True,
#     device=get_device()
#     )
