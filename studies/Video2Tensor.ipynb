# %%
import os
import torch
import itertools
import torchvision

# %%
os.getcwd()
# Out:
# '/Users/ahmedsalih/PycharmProjects/TikTokProject'

# %%
"""
Based off of https://pytorch.org/vision/stable/io.html
I needed to add av pkg into our env from assignment 2 (conda install -c conda-forge av)
"""

# %%
top_level_path = f'{os.getcwd()}/video_archive/videos'
video_list = os.listdir(top_level_path)

# %%
video_path = f"{top_level_path}/{video_list[1]}"
video_path
# Out:
# '/Users/ahmedsalih/PycharmProjects/TikTokProject/video_archive/videos/6892805816492084481.mp4'

# %%
# Constructor allocates memory and a threaded decoder
# instance per video. At the moment it takes two arguments:
# path to the video file, and a wanted stream.
reader = torchvision.io.VideoReader(video_path, "video")

# %%
# The information about the video can be retrieved using the
# `get_metadata()` method. It returns a dictionary for every stream, with
# duration and other relevant metadata (often frame rate)
reader_md = reader.get_metadata()
reader_md
# Out:
# {'video': {'fps': [29.97], 'duration': [7.07374040707374]},
#  'audio': {'framerate': [44100.0], 'duration': [7.057006802721088]}}

# %%
# metadata is structured as a dict of dicts with following structure
# {"stream_type": {"attribute": [attribute per stream]}}
#
# following would print out the list of frame rates for every present video stream
print(reader_md["video"]["fps"])
# Out:
# [29.97]

# %%
# we explicitly select the stream we would like to operate on. In
# the constructor we select a default video stream, but
# in practice, we can set whichever stream we would like
reader.set_current_stream("audio")

frames = []  # we are going to save the frames here.
ptss = []  # pts is a presentation timestamp in seconds (float) of each frame
for frame in reader:
    frames.append(frame['data'])
    ptss.append(frame['pts'])

# %%
def process_video(video_object_path, start=0, end=None, read_video=True, read_audio=True):
    """
    Based off of https://pytorch.org/vision/main/auto_examples/plot_video_api.html#sphx-glr-auto-examples-plot-video-api-py



    """
    if end is None:
        end = float("inf")
    if end < start:
        raise ValueError(
            "end time should be larger than start time, got "
            f"start time={start} and end time={end}"
        )

    video_object = torchvision.io.VideoReader(video_object_path, "video")

    video_frames = torch.empty(0)
    video_pts = []
    if read_video:
        video_object.set_current_stream("video")
        frames = []
        for frame in itertools.takewhile(lambda x: x['pts'] <= end, video_object.seek(start)):
            frames.append(frame['data'])
            video_pts.append(frame['pts'])
        if len(frames) > 0:
            video_frames = torch.stack(frames, 0)

    audio_frames = torch.empty(0)
    audio_pts = []
    if read_audio:
        video_object.set_current_stream("audio")
        frames = []
        for frame in itertools.takewhile(lambda x: x['pts'] <= end, video_object.seek(start)):
            frames.append(frame['data'])
            audio_pts.append(frame['pts'])
        if len(frames) > 0:
            audio_frames = torch.cat(frames, 0)

    return video_frames, audio_frames, (video_pts, audio_pts), video_object.get_metadata()

# %%
vf, af, info, meta =process_video(video_object_path=video_path)
print(f'video_frames: {vf.size()}\naudio_frames: {af.size()}')
print(f'metadata:\n{meta}')
# Out:
# video_frames: torch.Size([212, 3, 1024, 576])
# audio_frames: torch.Size([309248, 2])
# metadata:
# {'video': {'fps': [29.97], 'duration': [7.07374040707374]}, 'audio': {'framerate': [44100.0], 'duration': [7.057006802721088]}}

# %%
for tiktok_video in video_list:
    video_path = f"{top_level_path}/{tiktok_video}"
    print(tiktok_video)
    vf, af, info, meta =process_video(video_object_path=video_path)
    print(f'video_frames: {vf.size()}\naudio_frames: {af.size()}')
    print(f'metadata:\n{meta}\n\n')
# Out:
# 6886856236667636993.mp4
# video_frames: torch.Size([372, 3, 1024, 576])
# audio_frames: torch.Size([651264, 2])
# metadata:
# {'video': {'fps': [25.0], 'duration': [14.88]}, 'audio': {'framerate': [44100.0], 'duration': [14.812993197278912]}}
#
#
# 6892805816492084481.mp4
# video_frames: torch.Size([212, 3, 1024, 576])
# audio_frames: torch.Size([309248, 2])
# metadata:
# {'video': {'fps': [29.97], 'duration': [7.07374040707374]}, 'audio': {'framerate': [44100.0], 'duration': [7.057006802721088]}}
#
#
# 6885791166248340737.mp4
# video_frames: torch.Size([701, 3, 1024, 576])
# audio_frames: torch.Size([1061888, 2])
# metadata:
# {'video': {'fps': [29.0], 'duration': [24.17241379310345]}, 'audio': {'framerate': [44100.0], 'duration': [24.123990929705215]}}
#
#
# 6893611785295793410.mp4
# video_frames: torch.Size([377, 3, 960, 540])
# audio_frames: torch.Size([552960, 2])
# metadata:
# {'video': {'fps': [30.0], 'duration': [12.566666666666666]}, 'audio': {'framerate': [44100.0], 'duration': [12.585011337868481]}}
#
#
# 6892345024227331330.mp4
# video_frames: torch.Size([278, 3, 1024, 576])
# audio_frames: torch.Size([406528, 2])
# metadata:
# {'video': {'fps': [29.97], 'duration': [9.275942609275942]}, 'audio': {'framerate': [44100.0], 'duration': [9.262993197278911]}}
#
#
# 6885774617479302402.mp4
# video_frames: torch.Size([460, 3, 1024, 576])
# audio_frames: torch.Size([335872, 2])
# metadata:
# {'video': {'fps': [60.0], 'duration': [7.666666666666667]}, 'audio': {'framerate': [44100.0], 'duration': [7.660997732426304]}}
#
#
# 6905761532039220482.mp4
# video_frames: torch.Size([383, 3, 1024, 576])
# audio_frames: torch.Size([551036, 2])
# metadata:
# {'video': {'fps': [30.0], 'duration': [12.766666666666667]}, 'audio': {'framerate': [44100.0], 'duration': [12.722993197278912]}}
#
#
# 6908110392422092033.mp4
# video_frames: torch.Size([497, 3, 1024, 576])
# audio_frames: torch.Size([360572, 2])
# metadata:
# {'video': {'fps': [59.0], 'duration': [8.423728813559322]}, 'audio': {'framerate': [44100.0], 'duration': [8.403990929705216]}}
#
#
# 6901995461238934785.mp4
# video_frames: torch.Size([452, 3, 1024, 576])
# audio_frames: torch.Size([661504, 2])
# metadata:
# {'video': {'fps': [30.0], 'duration': [15.066666666666666]}, 'audio': {'framerate': [44100.0], 'duration': [15.04501133786848]}}
#
#
# 6888474204623195397.mp4
# video_frames: torch.Size([293, 3, 960, 540])
# audio_frames: torch.Size([428032, 2])
# metadata:
# {'video': {'fps': [30.0], 'duration': [9.766666666666667]}, 'audio': {'framerate': [44100.0], 'duration': [9.750997732426304]}}
#
#
# 6907635850985704709.mp4
# video_frames: torch.Size([986, 3, 1024, 576])
# audio_frames: torch.Size([1437820, 2])
# metadata:
# {'video': {'fps': [30.0], 'duration': [32.86666666666667]}, 'audio': {'framerate': [44100.0], 'duration': [32.85399092970521]}}
#
#
# 6897535476454952194.mp4
# video_frames: torch.Size([1285, 3, 1024, 576])
# audio_frames: torch.Size([1885184, 2])
# metadata:
# {'video': {'fps': [30.0], 'duration': [42.833333333333336]}, 'audio': {'framerate': [44100.0], 'duration': [42.79399092970522]}}
#
#
# 6899141975178480898.mp4
# video_frames: torch.Size([300, 3, 1024, 576])
# audio_frames: torch.Size([430204, 2])
# metadata:
# {'video': {'fps': [30.0], 'duration': [10.0]}, 'audio': {'framerate': [44100.0], 'duration': [9.982993197278912]}}
#
#
# 6895420478932946177.mp4
# video_frames: torch.Size([795, 3, 960, 540])
# audio_frames: torch.Size([1165312, 2])
# metadata:
# {'video': {'fps': [30.0], 'duration': [26.5]}, 'audio': {'framerate': [44100.0], 'duration': [26.470997732426305]}}
#
#
# 6905816780938235138.mp4
# video_frames: torch.Size([307, 3, 1024, 576])
# audio_frames: torch.Size([440444, 2])
# metadata:
# {'video': {'fps': [30.0], 'duration': [10.233333333333333]}, 'audio': {'framerate': [44100.0], 'duration': [10.21501133786848]}}
#
#
# 6900344945777872133.mp4
# video_frames: torch.Size([458, 3, 1024, 576])
# audio_frames: torch.Size([670720, 2])
# metadata:
# {'video': {'fps': [30.0], 'duration': [15.266666666666667]}, 'audio': {'framerate': [44100.0], 'duration': [15.253990929705216]}}
#
#
# 6902459846260559106.mp4
# video_frames: torch.Size([336, 3, 1024, 576])
# audio_frames: torch.Size([638976, 2])
# metadata:
# {'video': {'fps': [23.0], 'duration': [14.608695652173912]}, 'audio': {'framerate': [44100.0], 'duration': [14.533990929705215]}}
#
#
# 6906818204966915330.mp4
# video_frames: torch.Size([338, 3, 1024, 576])
# audio_frames: torch.Size([485500, 2])
# metadata:
# {'video': {'fps': [29.97], 'duration': [11.277944611277945]}, 'audio': {'framerate': [44100.0], 'duration': [11.26]}}
#
#
# 6885565252151315718.mp4
# video_frames: torch.Size([531, 3, 1024, 576])
# audio_frames: torch.Size([776192, 2])
# metadata:
# {'video': {'fps': [30.0], 'duration': [17.7]}, 'audio': {'framerate': [44100.0], 'duration': [17.647006802721087]}}
#
#
# 6881624031561354498.mp4
# video_frames: torch.Size([1577, 3, 960, 540])
# audio_frames: torch.Size([2394112, 2])
# metadata:
# {'video': {'fps': [29.0], 'duration': [54.37931034482759]}, 'audio': {'framerate': [44100.0], 'duration': [54.33299319727891]}}
#
#
# 6884266018936573189.mp4
# video_frames: torch.Size([351, 3, 1024, 576])
# audio_frames: torch.Size([514048, 2])
# metadata:
# {'video': {'fps': [29.97], 'duration': [11.711711711711711]}, 'audio': {'framerate': [44100.0], 'duration': [11.700997732426304]}}
#
#
# 6906776161221758210.mp4
# video_frames: torch.Size([869, 3, 982, 552])
# audio_frames: torch.Size([1265788, 2])
# metadata:
# {'video': {'fps': [30.0], 'duration': [28.966666666666665]}, 'audio': {'framerate': [44100.0], 'duration': [28.95299319727891]}}
#
#
# 6906940104053476609.mp4
# video_frames: torch.Size([260, 3, 1024, 576])
# audio_frames: torch.Size([370812, 2])
# metadata:
# {'video': {'fps': [30.0], 'duration': [8.666666666666666]}, 'audio': {'framerate': [44100.0], 'duration': [8.659002267573696]}}
#
#
# 6884574278134582529.mp4
# video_frames: torch.Size([594, 3, 1024, 576])
# audio_frames: torch.Size([886784, 2])
# metadata:
# {'video': {'fps': [29.405940594059405], 'duration': [20.2]}, 'audio': {'framerate': [44100.0], 'duration': [20.15299319727891]}}
#
#
# 6884114945026411778.mp4
# video_frames: torch.Size([620, 3, 768, 576])
# audio_frames: torch.Size([544768, 2])
# metadata:
# {'video': {'fps': [50.0], 'duration': [12.42]}, 'audio': {'framerate': [44100.0], 'duration': [12.398004535147392]}}
#
#
# 6882870430625975557.mp4
# video_frames: torch.Size([364, 3, 1024, 576])
# audio_frames: torch.Size([549888, 2])
# metadata:
# {'video': {'fps': [29.0], 'duration': [12.551724137931034]}, 'audio': {'framerate': [44100.0], 'duration': [12.513990929705216]}}
#
#
# 6908295874653342978.mp4
# video_frames: torch.Size([452, 3, 1024, 576])
# audio_frames: torch.Size([653436, 2])
# metadata:
# {'video': {'fps': [29.97], 'duration': [15.081748415081748]}, 'audio': {'framerate': [44100.0], 'duration': [15.068004535147391]}}
#
#
# 6880924761333959938.mp4
# video_frames: torch.Size([452, 3, 1024, 576])
# audio_frames: torch.Size([661504, 2])
# metadata:
# {'video': {'fps': [30.0], 'duration': [15.066666666666666]}, 'audio': {'framerate': [44100.0], 'duration': [15.04501133786848]}}
#
#
# 6905763366166367489.mp4
# video_frames: torch.Size([450, 3, 1024, 576])
# audio_frames: torch.Size([653436, 2])
# metadata:
# {'video': {'fps': [29.903547671840354], 'duration': [15.048381715048382]}, 'audio': {'framerate': [44100.0], 'duration': [15.068004535147391]}}
#
#
# 6895741298297359617.mp4
# video_frames: torch.Size([468, 3, 1024, 576])
# audio_frames: torch.Size([685056, 2])
# metadata:
# {'video': {'fps': [30.0], 'duration': [15.6]}, 'audio': {'framerate': [44100.0], 'duration': [15.579002267573696]}}
#
#
# 6888428739861040386.mp4
# video_frames: torch.Size([640, 3, 1024, 576])
# audio_frames: torch.Size([939008, 2])
# metadata:
# {'video': {'fps': [30.0], 'duration': [21.333333333333332]}, 'audio': {'framerate': [44100.0], 'duration': [21.33800453514739]}}
#
#
# 6877411003160694017.mp4
# video_frames: torch.Size([420, 3, 1024, 576])
# audio_frames: torch.Size([612352, 2])
# metadata:
# {'video': {'fps': [29.85781990521327], 'duration': [14.066666666666666]}, 'audio': {'framerate': [44100.0], 'duration': [13.931995464852609]}}
#
#
# 6886472762878151937.mp4
# video_frames: torch.Size([212, 3, 1024, 576])
# audio_frames: torch.Size([308224, 2])
# metadata:
# {'video': {'fps': [30.0], 'duration': [7.066666666666666]}, 'audio': {'framerate': [44100.0], 'duration': [7.033990929705215]}}
#
#
# 6904422505843363077.mp4
# video_frames: torch.Size([452, 3, 1024, 576])
# audio_frames: torch.Size([653436, 2])
# metadata:
# {'video': {'fps': [30.0], 'duration': [15.066666666666666]}, 'audio': {'framerate': [44100.0], 'duration': [15.04501133786848]}}
#
#
# 6902941615376157954.mp4
# video_frames: torch.Size([197, 3, 1024, 576])
# audio_frames: torch.Size([288768, 2])
# metadata:
# {'video': {'fps': [29.97], 'duration': [6.57323990657324]}, 'audio': {'framerate': [44100.0], 'duration': [6.592993197278911]}}
#
#
# 6892582021672013061.mp4
# video_frames: torch.Size([225, 3, 576, 648])
# audio_frames: torch.Size([327680, 2])
# metadata:
# {'video': {'fps': [30.0], 'duration': [7.5]}, 'audio': {'framerate': [44100.0], 'duration': [7.475011337868481]}}
#
#
# 6904344469747911942.mp4
# video_frames: torch.Size([414, 3, 1024, 576])
# audio_frames: torch.Size([598140, 2])
# metadata:
# {'video': {'fps': [29.97], 'duration': [13.813813813813814]}, 'audio': {'framerate': [44100.0], 'duration': [13.790997732426304]}}
#
#
# 6898295232723471617.mp4
# video_frames: torch.Size([420, 3, 1024, 576])
# audio_frames: torch.Size([626812, 2])
# metadata:
# {'video': {'fps': [29.0], 'duration': [14.482758620689655]}, 'audio': {'framerate': [44100.0], 'duration': [14.440997732426304]}}
#
#
# 6905139893425474818.mp4
# video_frames: torch.Size([443, 3, 848, 480])
# audio_frames: torch.Size([661628, 2])
# metadata:
# {'video': {'fps': [29.0], 'duration': [15.275862068965518]}, 'audio': {'framerate': [44100.0], 'duration': [15.23]}}
#
#
# 6907268705248464129.mp4
# video_frames: torch.Size([545, 3, 960, 540])
# audio_frames: torch.Size([817276, 2])
# metadata:
# {'video': {'fps': [29.0], 'duration': [18.79310344827586]}, 'audio': {'framerate': [44100.0], 'duration': [18.76]}}
#
#
# 6902436491536944386.mp4
# video_frames: torch.Size([527, 3, 1024, 576])
# audio_frames: torch.Size([772096, 2])
# metadata:
# {'video': {'fps': [30.0], 'duration': [17.566666666666666]}, 'audio': {'framerate': [44100.0], 'duration': [17.552993197278912]}}
#
#
# 6899861794760690945.mp4
# video_frames: torch.Size([285, 3, 960, 540])
# audio_frames: torch.Size([407676, 2])
# metadata:
# {'video': {'fps': [30.0], 'duration': [9.5]}, 'audio': {'framerate': [44100.0], 'duration': [9.471995464852608]}}
#
#
# 6899784988095499522.mp4
# video_frames: torch.Size([300, 3, 1024, 576])
# audio_frames: torch.Size([430204, 2])
# metadata:
# {'video': {'fps': [30.0], 'duration': [10.0]}, 'audio': {'framerate': [44100.0], 'duration': [9.982993197278912]}}
#
#
# 6908179105494174982.mp4
# video_frames: torch.Size([2053, 3, 540, 960])
# audio_frames: torch.Size([1497212, 2])
# metadata:
# {'video': {'fps': [60.0], 'duration': [34.21666666666667]}, 'audio': {'framerate': [44100.0], 'duration': [34.2009977324263]}}
#
#
# 6885153736222706949.mp4
# video_frames: torch.Size([210, 3, 1024, 576])
# audio_frames: torch.Size([306176, 2])
# metadata:
# {'video': {'fps': [29.97], 'duration': [7.007007007007007]}, 'audio': {'framerate': [44100.0], 'duration': [6.988004535147392]}}
#
#
# 6894926988453186817.mp4
# video_frames: torch.Size([354, 3, 1024, 576])
# audio_frames: torch.Size([517120, 2])
# metadata:
# {'video': {'fps': [30.0], 'duration': [11.8]}, 'audio': {'framerate': [44100.0], 'duration': [11.770997732426304]}}
#
#
# 6882348124120108289.mp4
# video_frames: torch.Size([1087, 3, 480, 848])
# audio_frames: torch.Size([808960, 2])
# metadata:
# {'video': {'fps': [59.001], 'duration': [18.423416552261827]}, 'audio': {'framerate': [44100.0], 'duration': [18.39]}}
#
#
# 6896576430491143426.mp4
# video_frames: torch.Size([250, 3, 1024, 576])
# audio_frames: torch.Size([364544, 2])
# metadata:
# {'video': {'fps': [29.97], 'duration': [8.341675008341674]}, 'audio': {'framerate': [44100.0], 'duration': [8.310997732426303]}}
#
#
# 6884946806833188097.mp4
# video_frames: torch.Size([420, 3, 1024, 576])
# audio_frames: torch.Size([614400, 2])
# metadata:
# {'video': {'fps': [30.0], 'duration': [14.0]}, 'audio': {'framerate': [44100.0], 'duration': [13.977006802721089]}}
#
#
# 6901321371113032962.mp4
# video_frames: torch.Size([251, 3, 960, 540])
# audio_frames: torch.Size([365568, 2])
# metadata:
# {'video': {'fps': [30.0], 'duration': [8.366666666666667]}, 'audio': {'framerate': [44100.0], 'duration': [8.333990929705216]}}
#
#
# 6892756720829893890.mp4
# video_frames: torch.Size([256, 3, 1024, 576])
# audio_frames: torch.Size([378880, 2])
# metadata:
# {'video': {'fps': [30.0], 'duration': [8.533333333333333]}, 'audio': {'framerate': [44100.0], 'duration': [8.57845804988662]}}
#
#
# 6893481053441281282.mp4
# video_frames: torch.Size([317, 3, 1024, 576])
# audio_frames: torch.Size([464896, 2])
# metadata:
# {'video': {'fps': [29.97], 'duration': [10.577243910577243]}, 'audio': {'framerate': [44100.0], 'duration': [10.587006802721088]}}
#
#
# 6882758194754522369.mp4
# video_frames: torch.Size([499, 3, 1024, 576])
# audio_frames: torch.Size([362496, 2])
# metadata:
# {'video': {'fps': [60.0], 'duration': [8.316666666666666]}, 'audio': {'framerate': [44100.0], 'duration': [8.266009070294784]}}
#
#
# 6905464131097332997.mp4
# video_frames: torch.Size([1202, 3, 960, 540])
# audio_frames: torch.Size([1755260, 2])
# metadata:
# {'video': {'fps': [29.97], 'duration': [40.10677344010677]}, 'audio': {'framerate': [44100.0], 'duration': [40.029002267573695]}}
#
#
# 6905408660185320706.mp4
# video_frames: torch.Size([3482, 3, 960, 540])
# audio_frames: torch.Size([2590844, 2])
# metadata:
# {'video': {'fps': [59.0], 'duration': [59.016949152542374]}, 'audio': {'framerate': [44100.0], 'duration': [59.0]}}
#
#
# 6891747931905330433.mp4
# video_frames: torch.Size([452, 3, 1024, 576])
# audio_frames: torch.Size([662528, 2])
# metadata:
# {'video': {'fps': [30.0], 'duration': [15.066666666666666]}, 'audio': {'framerate': [44100.0], 'duration': [15.068004535147391]}}
#
#
# 6885861410329332998.mp4
# video_frames: torch.Size([1341, 3, 1024, 576])
# audio_frames: torch.Size([1970176, 2])
# metadata:
# {'video': {'fps': [29.97], 'duration': [44.74474474474474]}, 'audio': {'framerate': [44100.0], 'duration': [44.72]}}
#
#
# 6887853904697101570.mp4
# video_frames: torch.Size([1047, 3, 1024, 576])
# audio_frames: torch.Size([1538048, 2])
# metadata:
# {'video': {'fps': [29.97], 'duration': [34.93493493493494]}, 'audio': {'framerate': [44100.0], 'duration': [34.9209977324263]}}
#
#
# 6877337975030598917.mp4
# video_frames: torch.Size([1122, 3, 1024, 576])
# audio_frames: torch.Size([1647616, 2])
# metadata:
# {'video': {'fps': [30.0], 'duration': [37.4]}, 'audio': {'framerate': [44100.0], 'duration': [37.406009070294786]}}
#
#
# 6896522195581897989.mp4
# video_frames: torch.Size([452, 3, 1024, 576])
# audio_frames: torch.Size([661504, 2])
# metadata:
# {'video': {'fps': [30.0], 'duration': [15.066666666666666]}, 'audio': {'framerate': [44100.0], 'duration': [15.04501133786848]}}
#
#
# 6896474585798053121.mp4
# video_frames: torch.Size([488, 3, 1024, 576])
# audio_frames: torch.Size([713728, 2])
# metadata:
# {'video': {'fps': [30.0], 'duration': [16.266666666666666]}, 'audio': {'framerate': [44100.0], 'duration': [16.230997732426303]}}
#
#
# 6889466576051932421.mp4
# video_frames: torch.Size([387, 3, 1024, 576])
# audio_frames: torch.Size([567296, 2])
# metadata:
# {'video': {'fps': [30.0], 'duration': [12.9]}, 'audio': {'framerate': [44100.0], 'duration': [12.909002267573696]}}
#
#
# 6892096873453145350.mp4
# video_frames: torch.Size([415, 3, 1024, 576])
# audio_frames: torch.Size([607232, 2])
# metadata:
# {'video': {'fps': [29.97], 'duration': [13.84718051384718]}, 'audio': {'framerate': [44100.0], 'duration': [13.813990929705215]}}
#
#
# 6899867641570135302.mp4
# video_frames: torch.Size([452, 3, 1024, 576])
# audio_frames: torch.Size([662528, 2])
# metadata:
# {'video': {'fps': [29.97], 'duration': [15.081748415081748]}, 'audio': {'framerate': [44100.0], 'duration': [15.068004535147391]}}
#
#
# 6907971568165604610.mp4
# video_frames: torch.Size([237, 3, 960, 540])
# audio_frames: torch.Size([348284, 2])
# metadata:
# {'video': {'fps': [29.0], 'duration': [8.172413793103448]}, 'audio': {'framerate': [44100.0], 'duration': [8.12501133786848]}}
#
#
# 6888218363923942657.mp4
# video_frames: torch.Size([1455, 3, 1024, 576])
# audio_frames: torch.Size([1083392, 2])
# metadata:
# {'video': {'fps': [59.001], 'duration': [24.660598972898764]}, 'audio': {'framerate': [44100.0], 'duration': [24.61299319727891]}}
#
#
# 6903574645899939074.mp4
# video_frames: torch.Size([406, 3, 960, 540])
# audio_frames: torch.Size([593920, 2])
# metadata:
# {'video': {'fps': [30.0], 'duration': [13.533333333333333]}, 'audio': {'framerate': [44100.0], 'duration': [13.512993197278911]}}
#
#
# 6906126061696863489.mp4
# video_frames: torch.Size([282, 3, 1024, 576])
# audio_frames: torch.Size([483452, 2])
# metadata:
# {'video': {'fps': [25.0], 'duration': [11.28]}, 'audio': {'framerate': [44100.0], 'duration': [11.212993197278912]}}
#
#
# 6891973965238111489.mp4
# video_frames: torch.Size([452, 3, 960, 540])
# audio_frames: torch.Size([662528, 2])
# metadata:
# {'video': {'fps': [29.97], 'duration': [15.081748415081748]}, 'audio': {'framerate': [44100.0], 'duration': [15.068004535147391]}}
#
#
# 6884030480736324869.mp4
# video_frames: torch.Size([1773, 3, 1024, 576])
# audio_frames: torch.Size([2603008, 2])
# metadata:
# {'video': {'fps': [30.0], 'duration': [59.1]}, 'audio': {'framerate': [44100.0], 'duration': [59.07]}}
#
#
# 6877251331145370881.mp4
# video_frames: torch.Size([291, 3, 1024, 576])
# audio_frames: torch.Size([424960, 2])
# metadata:
# {'video': {'fps': [30.0], 'duration': [9.7]}, 'audio': {'framerate': [44100.0], 'duration': [9.682993197278911]}}
#
#
# 6877036154982616321.mp4
# video_frames: torch.Size([457, 3, 436, 240])
# audio_frames: torch.Size([663552, 2])
# metadata:
# {'video': {'fps': [30.303], 'duration': [15.081015081015082]}, 'audio': {'framerate': [44100.0], 'duration': [15.092993197278911]}}
#
#
# 6886450016785894658.mp4
# video_frames: torch.Size([376, 3, 1024, 576])
# audio_frames: torch.Size([563200, 2])
# metadata:
# {'video': {'fps': [29.287749347258487], 'duration': [12.838132269634297]}, 'audio': {'framerate': [44100.0], 'duration': [12.817006802721089]}}
#
#
# 6893035754067430658.mp4
# video_frames: torch.Size([585, 3, 1024, 576])
# audio_frames: torch.Size([425984, 2])
# metadata:
# {'video': {'fps': [60.0], 'duration': [9.75]}, 'audio': {'framerate': [44100.0], 'duration': [9.706009070294785]}}
#
#
# 6876369534018669825.mp4
# video_frames: torch.Size([623, 3, 1024, 576])
# audio_frames: torch.Size([913408, 2])
# metadata:
# {'video': {'fps': [29.97], 'duration': [20.787454120787455]}, 'audio': {'framerate': [44100.0], 'duration': [20.75700680272109]}}
#
#
# 6904391764824608005.mp4
# video_frames: torch.Size([1773, 3, 1024, 576])
# audio_frames: torch.Size([2596988, 2])
# metadata:
# {'video': {'fps': [30.0], 'duration': [59.1]}, 'audio': {'framerate': [44100.0], 'duration': [59.11600907029479]}}
#
#
# 6897328348192656641.mp4
# video_frames: torch.Size([1073, 3, 1024, 576])
# audio_frames: torch.Size([1576960, 2])
# metadata:
# {'video': {'fps': [30.0], 'duration': [35.766666666666666]}, 'audio': {'framerate': [44100.0], 'duration': [35.80501133786848]}}
#
#
# 6881414725075242246.mp4
# video_frames: torch.Size([260, 3, 1024, 576])
# audio_frames: torch.Size([379904, 2])
# metadata:
# {'video': {'fps': [29.97], 'duration': [8.675342008675342]}, 'audio': {'framerate': [44100.0], 'duration': [8.66]}}
#
#
# 6890594872328195333.mp4
# video_frames: torch.Size([1763, 3, 1024, 576])
# audio_frames: torch.Size([2587648, 2])
# metadata:
# {'video': {'fps': [30.0], 'duration': [58.766666666666666]}, 'audio': {'framerate': [44100.0], 'duration': [58.72299319727891]}}
#
#
# 6886527878100438273.mp4
# video_frames: torch.Size([1183, 3, 1024, 576])
# audio_frames: torch.Size([2046976, 2])
# metadata:
# {'video': {'fps': [25.559956787900614], 'duration': [46.28333333333333]}, 'audio': {'framerate': [44100.0], 'duration': [46.46299319727891]}}
#
#
# 6885802277555293441.mp4
# video_frames: torch.Size([569, 3, 1024, 576])
# audio_frames: torch.Size([833536, 2])
# metadata:
# {'video': {'fps': [30.0], 'duration': [18.966666666666665]}, 'audio': {'framerate': [44100.0], 'duration': [18.946009070294785]}}
#
#
# 6891641815447932166.mp4
# video_frames: torch.Size([1068, 3, 1024, 576])
# audio_frames: torch.Size([1568768, 2])
# metadata:
# {'video': {'fps': [30.0], 'duration': [35.6]}, 'audio': {'framerate': [44100.0], 'duration': [35.61800453514739]}}
#
#
# 6903809474268646658.mp4
# video_frames: torch.Size([354, 3, 576, 1024])
# audio_frames: torch.Size([517120, 2])
# metadata:
# {'video': {'fps': [30.0], 'duration': [11.8]}, 'audio': {'framerate': [44100.0], 'duration': [11.771995464852608]}}
#
#
# 6906649897869659394.mp4
# video_frames: torch.Size([884, 3, 576, 576])
# audio_frames: torch.Size([1286268, 2])
# metadata:
# {'video': {'fps': [30.0], 'duration': [29.466666666666665]}, 'audio': {'framerate': [44100.0], 'duration': [29.419002267573696]}}
#
#
# 6876805952117558529.mp4
# video_frames: torch.Size([1745, 3, 1024, 576])
# audio_frames: torch.Size([2564096, 2])
# metadata:
# {'video': {'fps': [29.97], 'duration': [58.22489155822489]}, 'audio': {'framerate': [44100.0], 'duration': [58.18800453514739]}}
#
#
# 6876512902929599745.mp4
# video_frames: torch.Size([363, 3, 960, 540])
# audio_frames: torch.Size([530432, 2])
# metadata:
# {'video': {'fps': [30.0], 'duration': [12.1]}, 'audio': {'framerate': [44100.0], 'duration': [12.072993197278912]}}
#
#
# 6888753654594145537.mp4
# video_frames: torch.Size([1196, 3, 1024, 576])
# audio_frames: torch.Size([876544, 2])
# metadata:
# {'video': {'fps': [60.0], 'duration': [19.933333333333334]}, 'audio': {'framerate': [44100.0], 'duration': [19.920997732426304]}}
#
#
# 6884646106970590470.mp4
# video_frames: torch.Size([404, 3, 1024, 576])
# audio_frames: torch.Size([610304, 2])
# metadata:
# {'video': {'fps': [29.0], 'duration': [13.931034482758621]}, 'audio': {'framerate': [44100.0], 'duration': [13.883990929705215]}}
#
#
# 6884860645364354306.mp4
# video_frames: torch.Size([177, 3, 1024, 576])
# audio_frames: torch.Size([258048, 2])
# metadata:
# {'video': {'fps': [29.97], 'duration': [5.905905905905906]}, 'audio': {'framerate': [44100.0], 'duration': [5.8960090702947845]}}
#
#
# 6897625010668637441.mp4
# video_frames: torch.Size([843, 3, 960, 540])
# audio_frames: torch.Size([1235968, 2])
# metadata:
# {'video': {'fps': [30.0], 'duration': [28.1]}, 'audio': {'framerate': [44100.0], 'duration': [28.070997732426303]}}
#
#
# 6883928153727831297.mp4
# video_frames: torch.Size([241, 3, 1024, 576])
# audio_frames: torch.Size([353280, 2])
# metadata:
# {'video': {'fps': [30.0], 'duration': [8.033333333333333]}, 'audio': {'framerate': [44100.0], 'duration': [8.056009070294785]}}
#
#
# 6894377684403604738.mp4
# video_frames: torch.Size([341, 3, 1024, 576])
# audio_frames: torch.Size([493568, 2])
# metadata:
# {'video': {'fps': [30.303], 'duration': [11.253011253011254]}, 'audio': {'framerate': [44100.0], 'duration': [11.238004535147393]}}
#
#
# 6892015573861993730.mp4
# video_frames: torch.Size([304, 3, 1024, 576])
# audio_frames: torch.Size([443392, 2])
# metadata:
# {'video': {'fps': [30.0], 'duration': [10.133333333333333]}, 'audio': {'framerate': [44100.0], 'duration': [10.099002267573697]}}
#
#
# 6889092649895087362.mp4
# video_frames: torch.Size([194, 3, 1024, 576])
# audio_frames: torch.Size([282624, 2])
# metadata:
# {'video': {'fps': [30.0], 'duration': [6.466666666666667]}, 'audio': {'framerate': [44100.0], 'duration': [6.453990929705215]}}
#
#
# 6897270609915661569.mp4
# video_frames: torch.Size([215, 3, 1024, 576])
# audio_frames: torch.Size([313344, 2])
# metadata:
# {'video': {'fps': [30.0], 'duration': [7.166666666666667]}, 'audio': {'framerate': [44100.0], 'duration': [7.15]}}
#
#
# 6898394169249762562.mp4
# video_frames: torch.Size([379, 3, 1040, 576])
# audio_frames: torch.Size([542844, 2])
# metadata:
# {'video': {'fps': [30.0], 'duration': [12.633333333333333]}, 'audio': {'framerate': [44100.0], 'duration': [12.561995464852608]}}
#
#
# 6899619652402449670.mp4
# video_frames: torch.Size([449, 3, 960, 540])
# audio_frames: torch.Size([658432, 2])
# metadata:
# {'video': {'fps': [30.0], 'duration': [14.966666666666667]}, 'audio': {'framerate': [44100.0], 'duration': [14.977006802721089]}}
#
#
# 6905060523184901381.mp4
# video_frames: torch.Size([643, 3, 1024, 576])
# audio_frames: torch.Size([934012, 2])
# metadata:
# {'video': {'fps': [30.0], 'duration': [21.433333333333334]}, 'audio': {'framerate': [44100.0], 'duration': [21.40700680272109]}}
#
#
# 6897251091910528257.mp4
# video_frames: torch.Size([212, 3, 1024, 576])
# audio_frames: torch.Size([307200, 2])
# metadata:
# {'video': {'fps': [30.0], 'duration': [7.066666666666666]}, 'audio': {'framerate': [44100.0], 'duration': [7.011995464852608]}}
#
#
# 6890871255134752006.mp4
# video_frames: torch.Size([408, 3, 576, 1024])
# audio_frames: torch.Size([576512, 2])
# metadata:
# {'video': {'fps': [31.0], 'duration': [13.161290322580646]}, 'audio': {'framerate': [44100.0], 'duration': [13.118004535147392]}}
#
#
# 6895703273773321474.mp4
# video_frames: torch.Size([425, 3, 1024, 576])
# audio_frames: torch.Size([620544, 2])
# metadata:
# {'video': {'fps': [30.0], 'duration': [14.166666666666666]}, 'audio': {'framerate': [44100.0], 'duration': [14.118004535147392]}}
#
#
# 6879439037619342598.mp4
# video_frames: torch.Size([420, 3, 1024, 576])
# audio_frames: torch.Size([617472, 2])
# metadata:
# {'video': {'fps': [30.0357568533969], 'duration': [13.983333333333333]}, 'audio': {'framerate': [44100.0], 'duration': [14.048004535147392]}}
#
#
# 6888423046529518853.mp4
# video_frames: torch.Size([1714, 3, 1024, 576])
# audio_frames: torch.Size([2601984, 2])
# metadata:
# {'video': {'fps': [29.0], 'duration': [59.10344827586207]}, 'audio': {'framerate': [44100.0], 'duration': [59.047006802721086]}}
#
#
# 6905378711986801922.mp4
# video_frames: torch.Size([450, 3, 1024, 576])
# audio_frames: torch.Size([667604, 2])
# metadata:
# {'video': {'fps': [29.86725663716814], 'duration': [15.066666666666666]}, 'audio': {'framerate': [44100.0], 'duration': [15.152993197278912]}}
#
#
# 6888353150521134338.mp4
# video_frames: torch.Size([626, 3, 1024, 576])
# audio_frames: torch.Size([947200, 2])
# metadata:
# {'video': {'fps': [29.0], 'duration': [21.586206896551722]}, 'audio': {'framerate': [44100.0], 'duration': [21.52299319727891]}}
#
#
# 6883622094190497025.mp4
# video_frames: torch.Size([211, 3, 960, 540])
# audio_frames: torch.Size([308224, 2])
# metadata:
# {'video': {'fps': [30.0], 'duration': [7.033333333333333]}, 'audio': {'framerate': [44100.0], 'duration': [7.033990929705215]}}
#
#
# 6901420903322635525.mp4
# video_frames: torch.Size([1262, 3, 960, 540])
# audio_frames: torch.Size([1843324, 2])
# metadata:
# {'video': {'fps': [30.0], 'duration': [42.06666666666667]}, 'audio': {'framerate': [44100.0], 'duration': [42.02600907029478]}}
#
#
# 6879699550303538434.mp4
# video_frames: torch.Size([448, 3, 960, 544])
# audio_frames: torch.Size([656384, 2])
# metadata:
# {'video': {'fps': [30.0], 'duration': [14.933333333333334]}, 'audio': {'framerate': [44100.0], 'duration': [14.93]}}
#
#
# 6907614572048305409.mp4
# video_frames: torch.Size([419, 3, 1024, 576])
# audio_frames: torch.Size([606332, 2])
# metadata:
# {'video': {'fps': [30.0], 'duration': [13.966666666666667]}, 'audio': {'framerate': [44100.0], 'duration': [13.977006802721089]}}
#
#
# 6884933059758755073.mp4
# video_frames: torch.Size([449, 3, 1024, 576])
# audio_frames: torch.Size([658432, 2])
# metadata:
# {'video': {'fps': [30.0], 'duration': [14.966666666666667]}, 'audio': {'framerate': [44100.0], 'duration': [14.97501133786848]}}
#
#
# 6902096916776209665.mp4
# video_frames: torch.Size([1270, 3, 1024, 576])
# audio_frames: torch.Size([1864704, 2])
# metadata:
# {'video': {'fps': [30.0], 'duration': [42.333333333333336]}, 'audio': {'framerate': [44100.0], 'duration': [42.33]}}
#
#
# 6889521293306236161.mp4
# video_frames: torch.Size([382, 3, 1024, 576])
# audio_frames: torch.Size([557056, 2])
# metadata:
# {'video': {'fps': [30.0], 'duration': [12.733333333333333]}, 'audio': {'framerate': [44100.0], 'duration': [12.677006802721088]}}
#
#
# 6900076260693724417.mp4
# video_frames: torch.Size([285, 3, 1024, 576])
# audio_frames: torch.Size([405628, 2])
# metadata:
# {'video': {'fps': [30.0], 'duration': [9.5]}, 'audio': {'framerate': [44100.0], 'duration': [9.427006802721088]}}
#
#
# 6903552918159379713.mp4
# video_frames: torch.Size([464, 3, 1024, 576])
# audio_frames: torch.Size([678912, 2])
# metadata:
# {'video': {'fps': [30.0], 'duration': [15.466666666666667]}, 'audio': {'framerate': [44100.0], 'duration': [15.44]}}
#
#
# 6883094233935252737.mp4
# video_frames: torch.Size([254, 3, 1024, 576])
# audio_frames: torch.Size([370688, 2])
# metadata:
# {'video': {'fps': [30.0], 'duration': [8.466666666666667]}, 'audio': {'framerate': [44100.0], 'duration': [8.450997732426304]}}
#
#
# 6899845326161595649.mp4
# video_frames: torch.Size([936, 3, 1024, 576])
# audio_frames: torch.Size([1368188, 2])
# metadata:
# {'video': {'fps': [30.0], 'duration': [31.2]}, 'audio': {'framerate': [44100.0], 'duration': [31.253990929705214]}}
#
#
# 6880501583231061249.mp4
# video_frames: torch.Size([456, 3, 540, 552])
# audio_frames: torch.Size([667648, 2])
# metadata:
# {'video': {'fps': [30.0], 'duration': [15.2]}, 'audio': {'framerate': [44100.0], 'duration': [15.183990929705216]}}
#
#
# 6907309069904776454.mp4
# video_frames: torch.Size([529, 3, 1024, 576])
# audio_frames: torch.Size([766076, 2])
# metadata:
# {'video': {'fps': [30.0], 'duration': [17.633333333333333]}, 'audio': {'framerate': [44100.0], 'duration': [17.599002267573695]}}
#
#
# 6886383962885737730.mp4
# video_frames: torch.Size([548, 3, 960, 540])
# audio_frames: torch.Size([802816, 2])
# metadata:
# {'video': {'fps': [30.0], 'duration': [18.266666666666666]}, 'audio': {'framerate': [44100.0], 'duration': [18.249002267573697]}}
#
#
# 6881841137934454017.mp4
# video_frames: torch.Size([422, 3, 848, 480])
# audio_frames: torch.Size([617472, 2])
# metadata:
# {'video': {'fps': [30.0], 'duration': [14.066666666666666]}, 'audio': {'framerate': [44100.0], 'duration': [14.048004535147392]}}
#
#
# 6904384164641000705.mp4
# video_frames: torch.Size([847, 3, 1022, 576])
# audio_frames: torch.Size([1235068, 2])
# metadata:
# {'video': {'fps': [30.0], 'duration': [28.233333333333334]}, 'audio': {'framerate': [44100.0], 'duration': [28.233990929705215]}}
#
#
# 6906571896683285761.mp4
# video_frames: torch.Size([440, 3, 1024, 576])
# audio_frames: torch.Size([647292, 2])
# metadata:
# {'video': {'fps': [29.566816143497757], 'duration': [14.881548214881548]}, 'audio': {'framerate': [44100.0], 'duration': [14.907006802721089]}}
#
#
# 6898332186299337986.mp4
# video_frames: torch.Size([375, 3, 1024, 576])
# audio_frames: torch.Size([540796, 2])
# metadata:
# {'video': {'fps': [30.0], 'duration': [12.5]}, 'audio': {'framerate': [44100.0], 'duration': [12.513990929705216]}}
#
#
# 6877816601308073218.mp4
# video_frames: torch.Size([821, 3, 848, 384])
# audio_frames: torch.Size([1133568, 2])
# metadata:
# {'video': {'fps': [32.00519143413368], 'duration': [25.683333333333334]}, 'audio': {'framerate': [44100.0], 'duration': [25.749002267573697]}}
#
#
# 6899852150793358594.mp4
# video_frames: torch.Size([665, 3, 1024, 576])
# audio_frames: torch.Size([479356, 2])
# metadata:
# {'video': {'fps': [60.0], 'duration': [11.1]}, 'audio': {'framerate': [44100.0], 'duration': [11.097006802721088]}}
#
#
# 6883894825855274242.mp4
# video_frames: torch.Size([354, 3, 1024, 576])
# audio_frames: torch.Size([517120, 2])
# metadata:
# {'video': {'fps': [30.0], 'duration': [11.8]}, 'audio': {'framerate': [44100.0], 'duration': [11.771995464852608]}}
#
#
# 6891793639643647238.mp4
# video_frames: torch.Size([1755, 3, 1024, 576])
# audio_frames: torch.Size([2579456, 2])
# metadata:
# {'video': {'fps': [29.97], 'duration': [58.55855855855856]}, 'audio': {'framerate': [44100.0], 'duration': [58.53600907029478]}}
#
#
# 6884868479267147010.mp4
# video_frames: torch.Size([460, 3, 1246, 576])
# audio_frames: torch.Size([544768, 2])
# metadata:
# {'video': {'fps': [37.0], 'duration': [12.432432432432432]}, 'audio': {'framerate': [44100.0], 'duration': [12.398004535147392]}}
#
#
# 6903908757386841346.mp4
# video_frames: torch.Size([252, 3, 1024, 576])
# audio_frames: torch.Size([367616, 2])
# metadata:
# {'video': {'fps': [29.97], 'duration': [8.408408408408409]}, 'audio': {'framerate': [44100.0], 'duration': [8.380997732426303]}}
#
#
# 6908143157616151813.mp4
# video_frames: torch.Size([505, 3, 1024, 576])
# audio_frames: torch.Size([731260, 2])
# metadata:
# {'video': {'fps': [30.0], 'duration': [16.833333333333332]}, 'audio': {'framerate': [44100.0], 'duration': [16.809002267573696]}}
#
#
# 6878165800902085890.mp4
# video_frames: torch.Size([449, 3, 960, 544])
# audio_frames: torch.Size([657408, 2])
# metadata:
# {'video': {'fps': [30.0], 'duration': [14.966666666666667]}, 'audio': {'framerate': [44100.0], 'duration': [14.953990929705215]}}
#
#
# 6893676462788840709.mp4
# video_frames: torch.Size([1715, 3, 1024, 576])
# audio_frames: torch.Size([2605056, 2])
# metadata:
# {'video': {'fps': [29.0], 'duration': [59.13793103448276]}, 'audio': {'framerate': [44100.0], 'duration': [59.11600907029479]}}
#
#
# 6876262384093236485.mp4
# video_frames: torch.Size([254, 3, 960, 540])
# audio_frames: torch.Size([370688, 2])
# metadata:
# {'video': {'fps': [30.0], 'duration': [8.466666666666667]}, 'audio': {'framerate': [44100.0], 'duration': [8.450997732426304]}}
#
#
# 6880839179677256962.mp4
# video_frames: torch.Size([452, 3, 960, 540])
# audio_frames: torch.Size([662528, 2])
# metadata:
# {'video': {'fps': [29.97], 'duration': [15.081748415081748]}, 'audio': {'framerate': [44100.0], 'duration': [15.068004535147391]}}
#
#
# 6906170881626754309.mp4
# video_frames: torch.Size([360, 3, 1024, 576])
# audio_frames: torch.Size([520316, 2])
# metadata:
# {'video': {'fps': [29.97], 'duration': [12.012012012012011]}, 'audio': {'framerate': [44100.0], 'duration': [12.026009070294785]}}
#
#
# 6885276983870196994.mp4
# video_frames: torch.Size([659, 3, 960, 540])
# audio_frames: torch.Size([998400, 2])
# metadata:
# {'video': {'fps': [29.0], 'duration': [22.724137931034484]}, 'audio': {'framerate': [44100.0], 'duration': [22.683990929705214]}}
#
#
# 6895156886409137410.mp4
# video_frames: torch.Size([437, 3, 960, 540])
# audio_frames: torch.Size([318464, 2])
# metadata:
# {'video': {'fps': [60.0], 'duration': [7.283333333333333]}, 'audio': {'framerate': [44100.0], 'duration': [7.266009070294785]}}
#
#
# 6901655785407909121.mp4
# video_frames: torch.Size([499, 3, 576, 1040])
# audio_frames: torch.Size([730112, 2])
# metadata:
# {'video': {'fps': [30.0], 'duration': [16.633333333333333]}, 'audio': {'framerate': [44100.0], 'duration': [16.601995464852607]}}
#
#
# 6904271117783928065.mp4
# video_frames: torch.Size([281, 3, 960, 540])
# audio_frames: torch.Size([401532, 2])
# metadata:
# {'video': {'fps': [30.0], 'duration': [9.366666666666667]}, 'audio': {'framerate': [44100.0], 'duration': [9.356009070294785]}}
#
#
# 6901832410091064582.mp4
# video_frames: torch.Size([207, 3, 576, 648])
# audio_frames: torch.Size([301056, 2])
# metadata:
# {'video': {'fps': [30.0], 'duration': [6.9]}, 'audio': {'framerate': [44100.0], 'duration': [6.871995464852608]}}
#
#
# 6884239332329164034.mp4
# video_frames: torch.Size([329, 3, 1024, 576])
# audio_frames: torch.Size([480256, 2])
# metadata:
# {'video': {'fps': [30.0], 'duration': [10.966666666666667]}, 'audio': {'framerate': [44100.0], 'duration': [10.937006802721088]}}
#
#
# 6883011295763860738.mp4
# video_frames: torch.Size([428, 3, 540, 960])
# audio_frames: torch.Size([646144, 2])
# metadata:
# {'video': {'fps': [29.0], 'duration': [14.758620689655173]}, 'audio': {'framerate': [44100.0], 'duration': [14.697006802721088]}}
#
#
# 6899736406495677697.mp4
# video_frames: torch.Size([454, 3, 1024, 576])
# audio_frames: torch.Size([655484, 2])
# metadata:
# {'video': {'fps': [30.0], 'duration': [15.133333333333333]}, 'audio': {'framerate': [44100.0], 'duration': [15.092993197278911]}}
#
#
# 6881636686606912770.mp4
# video_frames: torch.Size([777, 3, 1024, 576])
# audio_frames: torch.Size([1138688, 2])
# metadata:
# {'video': {'fps': [30.0], 'duration': [25.9]}, 'audio': {'framerate': [44100.0], 'duration': [25.86700680272109]}}
#
#
# 6881297980456996097.mp4
# video_frames: torch.Size([681, 3, 1024, 576])
# audio_frames: torch.Size([998400, 2])
# metadata:
# {'video': {'fps': [29.91215226939971], 'duration': [22.766666666666666]}, 'audio': {'framerate': [44100.0], 'duration': [22.686009070294784]}}
#
#
# 6893282758790008065.mp4
# video_frames: torch.Size([1370, 3, 1024, 576])
# audio_frames: torch.Size([2009088, 2])
# metadata:
# {'video': {'fps': [30.0], 'duration': [45.666666666666664]}, 'audio': {'framerate': [44100.0], 'duration': [45.60399092970521]}}
#
#
# 6906504850712907009.mp4
# video_frames: torch.Size([402, 3, 626, 360])
# audio_frames: torch.Size([579708, 2])
# metadata:
# {'video': {'fps': [30.0], 'duration': [13.4]}, 'audio': {'framerate': [44100.0], 'duration': [13.373990929705215]}}
#
#
# 6905356954621824257.mp4
# video_frames: torch.Size([483, 3, 1024, 576])
# audio_frames: torch.Size([690300, 2])
# metadata:
# {'video': {'fps': [30.315204188481676], 'duration': [15.9325992659326]}, 'audio': {'framerate': [44100.0], 'duration': [15.903990929705216]}}
#
#
# 6898328700476083457.mp4
# video_frames: torch.Size([596, 3, 1024, 576])
# audio_frames: torch.Size([866428, 2])
# metadata:
# {'video': {'fps': [30.0], 'duration': [19.866666666666667]}, 'audio': {'framerate': [44100.0], 'duration': [19.873990929705215]}}
#
#
# 6876857501397159170.mp4
# video_frames: torch.Size([160, 3, 960, 540])
# audio_frames: torch.Size([232448, 2])
# metadata:
# {'video': {'fps': [29.97], 'duration': [5.338672005338672]}, 'audio': {'framerate': [44100.0], 'duration': [5.316009070294784]}}
#
#
# 6897699853720161542.mp4
# video_frames: torch.Size([452, 3, 960, 540])
# audio_frames: torch.Size([661504, 2])
# metadata:
# {'video': {'fps': [30.0], 'duration': [15.066666666666666]}, 'audio': {'framerate': [44100.0], 'duration': [15.04501133786848]}}
#
#
# 6896550572653120770.mp4
# video_frames: torch.Size([282, 3, 960, 540])
# audio_frames: torch.Size([424960, 2])
# metadata:
# {'video': {'fps': [29.0], 'duration': [9.724137931034482]}, 'audio': {'framerate': [44100.0], 'duration': [9.680997732426304]}}
#
#
# 6893846505656995073.mp4
# video_frames: torch.Size([902, 3, 1024, 576])
# audio_frames: torch.Size([660480, 2])
# metadata:
# {'video': {'fps': [60.0], 'duration': [15.033333333333333]}, 'audio': {'framerate': [44100.0], 'duration': [15.021995464852608]}}
#
#
# 6882547868792524034.mp4
# video_frames: torch.Size([168, 3, 960, 540])
# audio_frames: torch.Size([243712, 2])
# metadata:
# {'video': {'fps': [30.0], 'duration': [5.6]}, 'audio': {'framerate': [44100.0], 'duration': [5.570997732426304]}}
#
#
# 6906514963569888513.mp4
# video_frames: torch.Size([902, 3, 1024, 576])
# audio_frames: torch.Size([653436, 2])
# metadata:
# {'video': {'fps': [59.94], 'duration': [15.048381715048382]}, 'audio': {'framerate': [44100.0], 'duration': [15.04501133786848]}}
#
#
# 6880446332352367873.mp4
# video_frames: torch.Size([452, 3, 960, 540])
# audio_frames: torch.Size([662528, 2])
# metadata:
# {'video': {'fps': [30.0], 'duration': [15.066666666666666]}, 'audio': {'framerate': [44100.0], 'duration': [15.068004535147391]}}
#
#
# 6897185128322174209.mp4
# video_frames: torch.Size([271, 3, 1024, 576])
# audio_frames: torch.Size([396288, 2])
# metadata:
# {'video': {'fps': [29.889705882352942], 'duration': [9.066666666666666]}, 'audio': {'framerate': [44100.0], 'duration': [9.030997732426304]}}
#
#
# 6876007447883042050.mp4
# video_frames: torch.Size([300, 3, 576, 1024])
# audio_frames: torch.Size([440320, 2])
# metadata:
# {'video': {'fps': [29.771523178807946], 'duration': [10.076743410076743]}, 'audio': {'framerate': [44100.0], 'duration': [10.030997732426304]}}
#
#
# 6893140398403816706.mp4
# video_frames: torch.Size([255, 3, 1024, 576])
# audio_frames: torch.Size([371712, 2])
# metadata:
# {'video': {'fps': [30.0], 'duration': [8.5]}, 'audio': {'framerate': [44100.0], 'duration': [8.473990929705215]}}
#
#
# 6882735576160783617.mp4
# video_frames: torch.Size([1696, 3, 1024, 576])
# audio_frames: torch.Size([2489344, 2])
# metadata:
# {'video': {'fps': [30.01769911504425], 'duration': [56.5]}, 'audio': {'framerate': [44100.0], 'duration': [56.49299319727891]}}
#
#
# 6886192005270064386.mp4
# video_frames: torch.Size([2238, 3, 1024, 576])
# audio_frames: torch.Size([1670144, 2])
# metadata:
# {'video': {'fps': [59.0], 'duration': [37.932203389830505]}, 'audio': {'framerate': [44100.0], 'duration': [37.91700680272109]}}
#
#
# 6898035916682710274.mp4
# video_frames: torch.Size([443, 3, 1040, 576])
# audio_frames: torch.Size([321536, 2])
# metadata:
# {'video': {'fps': [60.0], 'duration': [7.383333333333334]}, 'audio': {'framerate': [44100.0], 'duration': [7.337006802721088]}}
#
#
# 6889446389349125377.mp4
# video_frames: torch.Size([446, 3, 960, 540])
# audio_frames: torch.Size([673792, 2])
# metadata:
# {'video': {'fps': [29.0], 'duration': [15.379310344827585]}, 'audio': {'framerate': [44100.0], 'duration': [15.323990929705216]}}
#
#
# 6875749962681044230.mp4
# video_frames: torch.Size([431, 3, 1082, 576])
# audio_frames: torch.Size([631808, 2])
# metadata:
# {'video': {'fps': [30.0], 'duration': [14.366666666666667]}, 'audio': {'framerate': [44100.0], 'duration': [14.371995464852608]}}
#
#
# 6908069845825359109.mp4
# video_frames: torch.Size([612, 3, 1024, 576])
# audio_frames: torch.Size([888956, 2])
# metadata:
# {'video': {'fps': [30.0], 'duration': [20.4]}, 'audio': {'framerate': [44100.0], 'duration': [20.38501133786848]}}
#
#
# 6903247940127640834.mp4
# video_frames: torch.Size([299, 3, 1024, 576])
# audio_frames: torch.Size([436224, 2])
# metadata:
# {'video': {'fps': [30.0], 'duration': [9.966666666666667]}, 'audio': {'framerate': [44100.0], 'duration': [9.937006802721088]}}
#
#
# 6902015702576762113.mp4
# video_frames: torch.Size([277, 3, 1024, 576])
# audio_frames: torch.Size([404480, 2])
# metadata:
# {'video': {'fps': [29.97], 'duration': [9.242575909242577]}, 'audio': {'framerate': [44100.0], 'duration': [9.21700680272109]}}
#
#
# 6908113835845012742.mp4
# video_frames: torch.Size([259, 3, 360, 636])
# audio_frames: torch.Size([370812, 2])
# metadata:
# {'video': {'fps': [30.0], 'duration': [8.633333333333333]}, 'audio': {'framerate': [44100.0], 'duration': [8.63700680272109]}}
#
#
# 6876716527186382081.mp4
# video_frames: torch.Size([452, 3, 1024, 576])
# audio_frames: torch.Size([662528, 2])
# metadata:
# {'video': {'fps': [29.97], 'duration': [15.081748415081748]}, 'audio': {'framerate': [44100.0], 'duration': [15.068004535147391]}}
#
#
# 6905462755919269121.mp4
# video_frames: torch.Size([385, 3, 1024, 576])
# audio_frames: torch.Size([555132, 2])
# metadata:
# {'video': {'fps': [30.0], 'duration': [12.833333333333334]}, 'audio': {'framerate': [44100.0], 'duration': [12.839002267573695]}}
#
#
# 6886291383246671109.mp4
# video_frames: torch.Size([1717, 3, 1024, 576])
# audio_frames: torch.Size([2522112, 2])
# metadata:
# {'video': {'fps': [30.0], 'duration': [57.233333333333334]}, 'audio': {'framerate': [44100.0], 'duration': [57.236009070294784]}}
#
#
# 6898499724245093633.mp4
# video_frames: torch.Size([212, 3, 960, 540])
# audio_frames: torch.Size([299132, 2])
# metadata:
# {'video': {'fps': [30.0], 'duration': [7.066666666666666]}, 'audio': {'framerate': [44100.0], 'duration': [7.033990929705215]}}
#
#
# 6904496575930731778.mp4
# video_frames: torch.Size([443, 3, 1024, 576])
# audio_frames: torch.Size([653436, 2])
# metadata:
# {'video': {'fps': [29.583], 'duration': [14.97481661765203]}, 'audio': {'framerate': [44100.0], 'duration': [15.046009070294785]}}
#
#
# 6908111363365768453.mp4
# video_frames: torch.Size([3423, 3, 826, 466])
# audio_frames: torch.Size([2590844, 2])
# metadata:
# {'video': {'fps': [58.0], 'duration': [59.01724137931034]}, 'audio': {'framerate': [44100.0], 'duration': [59.0]}}
#
#
# 6891275439826930946.mp4
# video_frames: torch.Size([903, 3, 1024, 576])
# audio_frames: torch.Size([1324032, 2])
# metadata:
# {'video': {'fps': [29.97], 'duration': [30.13013013013013]}, 'audio': {'framerate': [44100.0], 'duration': [30.06800453514739]}}
#
#
# 6898056960432704770.mp4
# video_frames: torch.Size([210, 3, 1024, 576])
# audio_frames: torch.Size([575488, 2])
# metadata:
# {'video': {'fps': [16.0], 'duration': [13.125]}, 'audio': {'framerate': [44100.0], 'duration': [13.096009070294784]}}
#
#
# 6897200586106752258.mp4
# video_frames: torch.Size([542, 3, 1024, 576])
# audio_frames: torch.Size([795648, 2])
# metadata:
# {'video': {'fps': [30.0], 'duration': [18.066666666666666]}, 'audio': {'framerate': [44100.0], 'duration': [18.08700680272109]}}
#
#
# 6908408424610974977.mp4
# video_frames: torch.Size([178, 3, 1024, 576])
# audio_frames: torch.Size([249980, 2])
# metadata:
# {'video': {'fps': [30.0], 'duration': [5.933333333333334]}, 'audio': {'framerate': [44100.0], 'duration': [5.919002267573696]}}
#
#
# 6880134891753852162.mp4
# video_frames: torch.Size([2343, 3, 1024, 576])
# audio_frames: torch.Size([1741824, 2])
# metadata:
# {'video': {'fps': [59.26675094816688], 'duration': [39.55]}, 'audio': {'framerate': [44100.0], 'duration': [39.541995464852604]}}
#
#
# 6904653648349957377.mp4
# video_frames: torch.Size([623, 3, 576, 1024])
# audio_frames: torch.Size([905340, 2])
# metadata:
# {'video': {'fps': [29.904], 'duration': [20.833333333333332]}, 'audio': {'framerate': [44100.0], 'duration': [20.758004535147393]}}
#
#
# 6875739742340762885.mp4
# video_frames: torch.Size([313, 3, 1024, 576])
# audio_frames: torch.Size([456704, 2])
# metadata:
# {'video': {'fps': [30.0], 'duration': [10.433333333333334]}, 'audio': {'framerate': [44100.0], 'duration': [10.400997732426303]}}
#
#
# 6895338661622123777.mp4
# video_frames: torch.Size([514, 3, 1024, 576])
# audio_frames: torch.Size([777216, 2])
# metadata:
# {'video': {'fps': [29.0], 'duration': [17.724137931034484]}, 'audio': {'framerate': [44100.0], 'duration': [17.669002267573696]}}
#
#
# 6878531534303857922.mp4
# video_frames: torch.Size([386, 3, 1024, 576])
# audio_frames: torch.Size([566272, 2])
# metadata:
# {'video': {'fps': [29.97], 'duration': [12.879546212879546]}, 'audio': {'framerate': [44100.0], 'duration': [12.886009070294785]}}
#
#
# 6902115301094116610.mp4
# video_frames: torch.Size([1593, 3, 1024, 576])
# audio_frames: torch.Size([2339840, 2])
# metadata:
# {'video': {'fps': [30.0], 'duration': [53.1]}, 'audio': {'framerate': [44100.0], 'duration': [53.10299319727891]}}
#
#
# 6898706823541542146.mp4
# video_frames: torch.Size([452, 3, 960, 540])
# audio_frames: torch.Size([653436, 2])
# metadata:
# {'video': {'fps': [29.97], 'duration': [15.081748415081748]}, 'audio': {'framerate': [44100.0], 'duration': [15.068004535147391]}}
#
#
# 6878254482698816770.mp4
# video_frames: torch.Size([492, 3, 976, 576])
# audio_frames: torch.Size([870400, 2])
# metadata:
# {'video': {'fps': [24.848484848484848], 'duration': [19.8]}, 'audio': {'framerate': [44100.0], 'duration': [19.782993197278913]}}
#
#
# 6878715680728911106.mp4
# video_frames: torch.Size([1728, 3, 1024, 576])
# audio_frames: torch.Size([1289216, 2])
# metadata:
# {'video': {'fps': [59.0], 'duration': [29.28813559322034]}, 'audio': {'framerate': [44100.0], 'duration': [29.279002267573695]}}
#
#
# 6879705053884697858.mp4
# video_frames: torch.Size([182, 3, 1024, 576])
# audio_frames: torch.Size([476160, 2])
# metadata:
# {'video': {'fps': [16.667], 'duration': [10.919781604367913]}, 'audio': {'framerate': [44100.0], 'duration': [10.843990929705216]}}
#
#
# 6879452591953153282.mp4
# video_frames: torch.Size([578, 3, 960, 540])
# audio_frames: torch.Size([846848, 2])
# metadata:
# {'video': {'fps': [30.0], 'duration': [19.266666666666666]}, 'audio': {'framerate': [44100.0], 'duration': [19.24800453514739]}}
#
#
# 6880928709956635909.mp4
# video_frames: torch.Size([251, 3, 1024, 576])
# audio_frames: torch.Size([365568, 2])
# metadata:
# {'video': {'fps': [30.0], 'duration': [8.366666666666667]}, 'audio': {'framerate': [44100.0], 'duration': [8.333990929705216]}}
#
#
# 6900932062853893378.mp4
# video_frames: torch.Size([188, 3, 1024, 576])
# audio_frames: torch.Size([273408, 2])
# metadata:
# {'video': {'fps': [30.0], 'duration': [6.266666666666667]}, 'audio': {'framerate': [44100.0], 'duration': [6.245011337868481]}}
#
#
# 6899737900120935681.mp4
# video_frames: torch.Size([451, 3, 576, 1024])
# audio_frames: torch.Size([673916, 2])
# metadata:
# {'video': {'fps': [29.0], 'duration': [15.551724137931034]}, 'audio': {'framerate': [44100.0], 'duration': [15.509002267573695]}}
#
#
# 6891183356097187074.mp4
# video_frames: torch.Size([1292, 3, 1024, 576])
# audio_frames: torch.Size([1896448, 2])
# metadata:
# {'video': {'fps': [30.0], 'duration': [43.06666666666667]}, 'audio': {'framerate': [44100.0], 'duration': [43.04800453514739]}}
#
#
# 6898107264805244162.mp4
# video_frames: torch.Size([294, 3, 960, 540])
# audio_frames: torch.Size([429056, 2])
# metadata:
# {'video': {'fps': [30.0], 'duration': [9.8]}, 'audio': {'framerate': [44100.0], 'duration': [9.773990929705215]}}
#
#
# 6899811757322194177.mp4
# video_frames: torch.Size([766, 3, 1024, 576])
# audio_frames: torch.Size([1114236, 2])
# ...
#
#
# 6904798749290286341.mp4
# video_frames: torch.Size([221, 3, 1024, 576])
# audio_frames: torch.Size([317564, 2])
# metadata:
# {'video': {'fps': [29.449743243243244], 'duration': [7.50430990771727]}, 'audio': {'framerate': [44100.0], 'duration': [7.43]}}
#
#
# 6891908752539274497.mp4
# video_frames: torch.Size([577, 3, 1024, 576])
# audio_frames: torch.Size([844800, 2])
# metadata:
# {'video': {'fps': [30.0], 'duration': [19.233333333333334]}, 'audio': {'framerate': [44100.0], 'duration': [19.20299319727891]}}
#
#
# 6891064220658502913.mp4
# video_frames: torch.Size([258, 3, 960, 540])
# audio_frames: torch.Size([375808, 2])
# metadata:
# {'video': {'fps': [30.0], 'duration': [8.6]}, 'audio': {'framerate': [44100.0], 'duration': [8.567006802721089]}}
#
#
# 6883484287434378497.mp4
# video_frames: torch.Size([403, 3, 1024, 576])
# audio_frames: torch.Size([589824, 2])
# metadata:
# {'video': {'fps': [29.97], 'duration': [13.44678011344678]}, 'audio': {'framerate': [44100.0], 'duration': [13.42]}}
#
#
# 6882598038947286274.mp4
# video_frames: torch.Size([915, 3, 1024, 576])
# audio_frames: torch.Size([1340416, 2])
# metadata:
# {'video': {'fps': [30.0], 'duration': [30.5]}, 'audio': {'framerate': [44100.0], 'duration': [30.440997732426304]}}
#
#
# 6886765050355289346.mp4
# video_frames: torch.Size([273, 3, 1024, 576])
# audio_frames: torch.Size([398336, 2])
# metadata:
# {'video': {'fps': [29.97], 'duration': [9.10910910910911]}, 'audio': {'framerate': [44100.0], 'duration': [9.077006802721089]}}
#
#
# 6881719705028021509.mp4
# video_frames: torch.Size([1662, 3, 1024, 576])
# audio_frames: torch.Size([2440192, 2])
# metadata:
# {'video': {'fps': [29.97], 'duration': [55.45545545545546]}, 'audio': {'framerate': [44100.0], 'duration': [55.37800453514739]}}
#
#
# 6889831681469975810.mp4
# video_frames: torch.Size([452, 3, 1024, 576])
# audio_frames: torch.Size([662528, 2])
# metadata:
# {'video': {'fps': [29.97], 'duration': [15.081748415081748]}, 'audio': {'framerate': [44100.0], 'duration': [15.068004535147391]}}
#
#
# 6893741937132604673.mp4
# video_frames: torch.Size([449, 3, 960, 540])
# audio_frames: torch.Size([658432, 2])
# metadata:
# {'video': {'fps': [30.0], 'duration': [14.966666666666667]}, 'audio': {'framerate': [44100.0], 'duration': [14.97501133786848]}}
#
#
# 6879476802050460934.mp4
# video_frames: torch.Size([1093, 3, 1024, 576])
# audio_frames: torch.Size([1602560, 2])
# metadata:
# {'video': {'fps': [29.97], 'duration': [36.4698031364698]}, 'audio': {'framerate': [44100.0], 'duration': [36.38399092970521]}}
#
#
# 6887618500307864833.mp4
# video_frames: torch.Size([416, 3, 960, 540])
# audio_frames: torch.Size([608256, 2])
# metadata:
# {'video': {'fps': [30.0], 'duration': [13.866666666666667]}, 'audio': {'framerate': [44100.0], 'duration': [13.838004535147393]}}
#
#
# 6896614154682125570.mp4
# video_frames: torch.Size([922, 3, 960, 540])
# audio_frames: torch.Size([1351680, 2])
# metadata:
# {'video': {'fps': [30.0], 'duration': [30.733333333333334]}, 'audio': {'framerate': [44100.0], 'duration': [30.69501133786848]}}
#
#
# 6906519148025629953.mp4
# video_frames: torch.Size([435, 3, 1024, 576])
# audio_frames: torch.Size([626812, 2])
# metadata:
# {'video': {'fps': [30.0], 'duration': [14.5]}, 'audio': {'framerate': [44100.0], 'duration': [14.440997732426304]}}
#
#
# 6908391851418471682.mp4
# video_frames: torch.Size([725, 3, 1024, 576])
# audio_frames: torch.Size([1048700, 2])
# metadata:
# {'video': {'fps': [30.22932592077832], 'duration': [23.983333333333334]}, 'audio': {'framerate': [44100.0], 'duration': [24.008004535147393]}}
#
#
# 6889712383049108737.mp4
# video_frames: torch.Size([458, 3, 1024, 576])
# audio_frames: torch.Size([671744, 2])
# metadata:
# {'video': {'fps': [30.0], 'duration': [15.266666666666667]}, 'audio': {'framerate': [44100.0], 'duration': [15.279002267573697]}}
#
#
# 6893869437884091649.mp4
# video_frames: torch.Size([394, 3, 1024, 576])
# audio_frames: torch.Size([576512, 2])
# metadata:
# {'video': {'fps': [30.0], 'duration': [13.133333333333333]}, 'audio': {'framerate': [44100.0], 'duration': [13.118004535147392]}}
#
#
# 6895916039683525890.mp4
# video_frames: torch.Size([811, 3, 960, 540])
# audio_frames: torch.Size([1188864, 2])
# metadata:
# {'video': {'fps': [30.0], 'duration': [27.033333333333335]}, 'audio': {'framerate': [44100.0], 'duration': [27.00299319727891]}}
#
#
# 6897397404421688578.mp4
# video_frames: torch.Size([2840, 3, 576, 1024])
# audio_frames: torch.Size([2085888, 2])
# metadata:
# {'video': {'fps': [60.0], 'duration': [47.333333333333336]}, 'audio': {'framerate': [44100.0], 'duration': [47.34501133786848]}}
#
#
# 6876643374548438274.mp4
# video_frames: torch.Size([1502, 3, 960, 540])
# audio_frames: torch.Size([1560576, 2])
# metadata:
# {'video': {'fps': [42.36953455571227], 'duration': [35.45]}, 'audio': {'framerate': [44100.0], 'duration': [35.431995464852605]}}
#
#
# 6892131074093223170.mp4
# video_frames: torch.Size([351, 3, 1024, 576])
# audio_frames: torch.Size([514048, 2])
# metadata:
# {'video': {'fps': [30.0], 'duration': [11.7]}, 'audio': {'framerate': [44100.0], 'duration': [11.70299319727891]}}
#
#
# 6882419822806699266.mp4
# video_frames: torch.Size([719, 3, 1024, 576])
# audio_frames: torch.Size([1041408, 2])
# metadata:
# {'video': {'fps': [30.371289640591968], 'duration': [23.673673673673672]}, 'audio': {'framerate': [44100.0], 'duration': [23.66]}}
#
#
# 6875378565614013697.mp4
# video_frames: torch.Size([225, 3, 1024, 576])
# audio_frames: torch.Size([326656, 2])
# metadata:
# {'video': {'fps': [30.0], 'duration': [7.5]}, 'audio': {'framerate': [44100.0], 'duration': [7.451995464852608]}}
#
#
# 6892201986381335810.mp4
# video_frames: torch.Size([1586, 3, 960, 540])
# audio_frames: torch.Size([2327552, 2])
# metadata:
# {'video': {'fps': [30.0], 'duration': [52.86666666666667]}, 'audio': {'framerate': [44100.0], 'duration': [52.82399092970522]}}
#
#
# 6879772200065436929.mp4
# video_frames: torch.Size([1255, 3, 1024, 576])
# audio_frames: torch.Size([923648, 2])
# metadata:
# {'video': {'fps': [59.95226730310262], 'duration': [20.95]}, 'audio': {'framerate': [44100.0], 'duration': [20.989002267573696]}}
#
#
# 6890298155766697221.mp4
# video_frames: torch.Size([452, 3, 1024, 576])
# audio_frames: torch.Size([661504, 2])
# metadata:
# {'video': {'fps': [30.0], 'duration': [15.066666666666666]}, 'audio': {'framerate': [44100.0], 'duration': [15.04501133786848]}}
#
#
# 6901122865928670466.mp4
# video_frames: torch.Size([1024, 3, 576, 1024])
# audio_frames: torch.Size([751616, 2])
# metadata:
# {'video': {'fps': [60.0], 'duration': [17.066666666666666]}, 'audio': {'framerate': [44100.0], 'duration': [17.09]}}
#
#
# 6888722307603336453.mp4
# video_frames: torch.Size([1662, 3, 1024, 576])
# audio_frames: torch.Size([2442240, 2])
# metadata:
# {'video': {'fps': [29.97], 'duration': [55.45545545545546]}, 'audio': {'framerate': [44100.0], 'duration': [55.42501133786848]}}
#
#
# 6883565215552654593.mp4
# video_frames: torch.Size([1623, 3, 1024, 576])
# audio_frames: torch.Size([2382848, 2])
# metadata:
# {'video': {'fps': [30.0], 'duration': [54.1]}, 'audio': {'framerate': [44100.0], 'duration': [54.07800453514739]}}
#
#
# 6884153193425636610.mp4
# video_frames: torch.Size([287, 3, 960, 540])
# audio_frames: torch.Size([418816, 2])
# metadata:
# {'video': {'fps': [30.0], 'duration': [9.566666666666666]}, 'audio': {'framerate': [44100.0], 'duration': [9.541995464852608]}}
#
#
# 6899557108593773829.mp4
# video_frames: torch.Size([843, 3, 1024, 576])
# audio_frames: torch.Size([1235968, 2])
# metadata:
# {'video': {'fps': [29.97], 'duration': [28.12812812812813]}, 'audio': {'framerate': [44100.0], 'duration': [28.070997732426303]}}
#
#
# 6898194233778261250.mp4
# video_frames: torch.Size([291, 3, 1024, 576])
# audio_frames: torch.Size([424960, 2])
# metadata:
# {'video': {'fps': [29.97], 'duration': [9.70970970970971]}, 'audio': {'framerate': [44100.0], 'duration': [9.680997732426304]}}
#
#
# 6875862825932180738.mp4
# video_frames: torch.Size([447, 3, 1024, 576])
# audio_frames: torch.Size([659456, 2])
# metadata:
# {'video': {'fps': [29.866369710467705], 'duration': [14.966666666666667]}, 'audio': {'framerate': [44100.0], 'duration': [15.0]}}
#
#
# 6877530962742217985.mp4
# video_frames: torch.Size([417, 3, 1024, 576])
# audio_frames: torch.Size([611328, 2])
# metadata:
# {'video': {'fps': [30.0], 'duration': [13.9]}, 'audio': {'framerate': [44100.0], 'duration': [13.907006802721089]}}
#
#
# 6907974329305156866.mp4
# video_frames: torch.Size([1772, 3, 960, 540])
# audio_frames: torch.Size([2592892, 2])
# metadata:
# {'video': {'fps': [30.0], 'duration': [59.06666666666667]}, 'audio': {'framerate': [44100.0], 'duration': [59.047006802721086]}}
#
#
# 6882670049648200962.mp4
# video_frames: torch.Size([210, 3, 1024, 576])
# audio_frames: torch.Size([575488, 2])
# metadata:
# {'video': {'fps': [16.0], 'duration': [13.125]}, 'audio': {'framerate': [44100.0], 'duration': [13.096009070294784]}}
#
#
# 6901723835310116101.mp4
# video_frames: torch.Size([279, 3, 1024, 576])
# audio_frames: torch.Size([407552, 2])
# metadata:
# {'video': {'fps': [30.0], 'duration': [9.3]}, 'audio': {'framerate': [44100.0], 'duration': [9.286009070294785]}}
#
#
# 6897916296025885954.mp4
# video_frames: torch.Size([348, 3, 1024, 576])
# audio_frames: torch.Size([506880, 2])
# metadata:
# {'video': {'fps': [30.0], 'duration': [11.6]}, 'audio': {'framerate': [44100.0], 'duration': [11.539002267573697]}}
#
#
# 6899497158769200385.mp4
# video_frames: torch.Size([190, 3, 1024, 576])
# audio_frames: torch.Size([276604, 2])
# metadata:
# {'video': {'fps': [29.0], 'duration': [6.551724137931035]}, 'audio': {'framerate': [44100.0], 'duration': [6.5]}}
#
#
# 6895497835681287426.mp4
# video_frames: torch.Size([886, 3, 1024, 576])
# audio_frames: torch.Size([1298432, 2])
# metadata:
# {'video': {'fps': [30.0], 'duration': [29.533333333333335]}, 'audio': {'framerate': [44100.0], 'duration': [29.488004535147393]}}
#
#
# 6908298047470472450.mp4
# video_frames: torch.Size([801, 3, 1024, 576])
# audio_frames: torch.Size([608380, 2])
# metadata:
# {'video': {'fps': [57.00368098159509], 'duration': [14.051724137931034]}, 'audio': {'framerate': [44100.0], 'duration': [14.046009070294785]}}
#
#
# 6900235731059494145.mp4
# video_frames: torch.Size([278, 3, 1024, 576])
# audio_frames: torch.Size([399484, 2])
# metadata:
# {'video': {'fps': [30.0], 'duration': [9.266666666666667]}, 'audio': {'framerate': [44100.0], 'duration': [9.288004535147392]}}
#
#
# 6887946160837790982.mp4
# video_frames: torch.Size([1193, 3, 1024, 576])
# audio_frames: torch.Size([1751040, 2])
# metadata:
# {'video': {'fps': [30.0], 'duration': [39.766666666666666]}, 'audio': {'framerate': [44100.0], 'duration': [39.750997732426306]}}
#
#
# 6899462833088531714.mp4
# video_frames: torch.Size([264, 3, 1024, 576])
# audio_frames: torch.Size([379004, 2])
# metadata:
# {'video': {'fps': [29.97], 'duration': [8.80880880880881]}, 'audio': {'framerate': [44100.0], 'duration': [8.821995464852607]}}
#
#
# 6886981950180003073.mp4
# video_frames: torch.Size([451, 3, 1024, 576])
# audio_frames: torch.Size([659456, 2])
# metadata:
# {'video': {'fps': [30.0], 'duration': [15.033333333333333]}, 'audio': {'framerate': [44100.0], 'duration': [15.0]}}
#
#
# 6881909763723037954.mp4
# video_frames: torch.Size([260, 3, 1024, 576])
# audio_frames: torch.Size([378880, 2])
# metadata:
# {'video': {'fps': [30.0], 'duration': [8.666666666666666]}, 'audio': {'framerate': [44100.0], 'duration': [8.636009070294785]}}
#
#
# 6892735023372389634.mp4
# video_frames: torch.Size([475, 3, 576, 824])
# audio_frames: torch.Size([695296, 2])
# metadata:
# {'video': {'fps': [30.0], 'duration': [15.833333333333334]}, 'audio': {'framerate': [44100.0], 'duration': [15.810997732426303]}}
#
#
# 6901344153343364354.mp4
# video_frames: torch.Size([358, 3, 1024, 576])
# audio_frames: torch.Size([521216, 2])
# metadata:
# {'video': {'fps': [30.0], 'duration': [11.933333333333334]}, 'audio': {'framerate': [44100.0], 'duration': [11.86501133786848]}}
#
#
# 6885726005357530370.mp4
# video_frames: torch.Size([206, 3, 960, 540])
# audio_frames: torch.Size([297984, 2])
# metadata:
# {'video': {'fps': [30.0], 'duration': [6.866666666666666]}, 'audio': {'framerate': [44100.0], 'duration': [6.802993197278911]}}
#
#
# 6875317312082201857.mp4
# video_frames: torch.Size([214, 3, 1024, 576])
# audio_frames: torch.Size([311296, 2])
# metadata:
# {'video': {'fps': [30.0], 'duration': [7.133333333333334]}, 'audio': {'framerate': [44100.0], 'duration': [7.1039909297052155]}}
#
#
# 6892449418851716354.mp4
# video_frames: torch.Size([396, 3, 1024, 576])
# audio_frames: torch.Size([578560, 2])
# metadata:
# {'video': {'fps': [30.0], 'duration': [13.2]}, 'audio': {'framerate': [44100.0], 'duration': [13.163990929705216]}}
#
#
# 6899519135198383361.mp4
# video_frames: torch.Size([1243, 3, 1024, 576])
# audio_frames: torch.Size([1816700, 2])
# metadata:
# {'video': {'fps': [29.97], 'duration': [41.47480814147481]}, 'audio': {'framerate': [44100.0], 'duration': [41.42299319727891]}}
#
#
# 6895042572994104581.mp4
# video_frames: torch.Size([356, 3, 1024, 576])
# audio_frames: torch.Size([520192, 2])
# metadata:
# {'video': {'fps': [30.0], 'duration': [11.866666666666667]}, 'audio': {'framerate': [44100.0], 'duration': [11.840997732426304]}}
#
#
# 6877458289978821889.mp4
# video_frames: torch.Size([451, 3, 1024, 576])
# audio_frames: torch.Size([662528, 2])
# metadata:
# {'video': {'fps': [29.97], 'duration': [15.048381715048382]}, 'audio': {'framerate': [44100.0], 'duration': [15.068004535147391]}}
#
#
# 6893521307023969538.mp4
# video_frames: torch.Size([417, 3, 1024, 576])
# audio_frames: torch.Size([610304, 2])
# metadata:
# {'video': {'fps': [29.97], 'duration': [13.913913913913914]}, 'audio': {'framerate': [44100.0], 'duration': [13.883990929705215]}}
#
#
# 6908266212787047686.mp4
# video_frames: torch.Size([299, 3, 1024, 576])
# audio_frames: torch.Size([428156, 2])
# metadata:
# {'video': {'fps': [30.0], 'duration': [9.966666666666667]}, 'audio': {'framerate': [44100.0], 'duration': [9.936009070294785]}}
#
#
# 6887605177591942405.mp4
# video_frames: torch.Size([1898, 3, 1024, 576])
# audio_frames: torch.Size([1392640, 2])
# metadata:
# {'video': {'fps': [60.0], 'duration': [31.633333333333333]}, 'audio': {'framerate': [44100.0], 'duration': [31.623990929705215]}}
#
#
# 6895048600355704070.mp4
# video_frames: torch.Size([451, 3, 1024, 576])
# audio_frames: torch.Size([661504, 2])
# metadata:
# {'video': {'fps': [30.0], 'duration': [15.033333333333333]}, 'audio': {'framerate': [44100.0], 'duration': [15.04501133786848]}}
#
#
# 6904978624085069057.mp4
# video_frames: torch.Size([838, 3, 960, 540])
# audio_frames: torch.Size([1466492, 2])
# metadata:
# {'video': {'fps': [25.0], 'duration': [33.52]}, 'audio': {'framerate': [44100.0], 'duration': [33.4809977324263]}}
#
#
# 6905831259478461698.mp4
# video_frames: torch.Size([414, 3, 1024, 576])
# audio_frames: torch.Size([596092, 2])
# metadata:
# {'video': {'fps': [30.0], 'duration': [13.8]}, 'audio': {'framerate': [44100.0], 'duration': [13.768004535147393]}}
#
#
# 6898791307016146177.mp4
# video_frames: torch.Size([2397, 3, 576, 1024])
# audio_frames: torch.Size([1753212, 2])
# metadata:
# {'video': {'fps': [59.94997915798249], 'duration': [39.983333333333334]}, 'audio': {'framerate': [44100.0], 'duration': [39.983990929705215]}}
#
#
# 6880877914078842113.mp4
# video_frames: torch.Size([442, 3, 1024, 576])
# audio_frames: torch.Size([659456, 2])
# metadata:
# {'video': {'fps': [29.583], 'duration': [14.94101341986952]}, 'audio': {'framerate': [44100.0], 'duration': [15.0]}}
#
#
# 6896548159820926209.mp4
# video_frames: torch.Size([406, 3, 1024, 576])
# audio_frames: torch.Size([592896, 2])
# metadata:
# {'video': {'fps': [30.0], 'duration': [13.533333333333333]}, 'audio': {'framerate': [44100.0], 'duration': [13.490997732426305]}}
#
#
# 6890707606579563781.mp4
# video_frames: torch.Size([957, 3, 1024, 576])
# audio_frames: torch.Size([1403904, 2])
# metadata:
# {'video': {'fps': [30.0], 'duration': [31.9]}, 'audio': {'framerate': [44100.0], 'duration': [31.879002267573696]}}
#
#
# 6896497936558001410.mp4
# video_frames: torch.Size([725, 3, 1024, 576])
# audio_frames: torch.Size([1062912, 2])
# metadata:
# {'video': {'fps': [29.97], 'duration': [24.190857524190857]}, 'audio': {'framerate': [44100.0], 'duration': [24.147006802721087]}}
#
#
# 6884795858827644161.mp4
# video_frames: torch.Size([210, 3, 1024, 576])
# audio_frames: torch.Size([575488, 2])
# metadata:
# {'video': {'fps': [16.0], 'duration': [13.125]}, 'audio': {'framerate': [44100.0], 'duration': [13.096009070294784]}}

# %%
# Parse out video count from JSON
